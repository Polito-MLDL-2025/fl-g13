# %%
import wandb
## read .env file
import dotenv

dotenv.load_dotenv()


# login by key in .env file
WANDB_API_KEY = dotenv.dotenv_values()["WANDB_API_KEY"]
wandb.login(key=WANDB_API_KEY)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\ADMIN\_netrc
# wandb: Currently logged in as: thanhnv-it23 (stefano-gamba-social-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
import wandb
import pandas as pd

# Connect to the existing run
api = wandb.Api()
url='stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64/runs/FL_Dino_Baseline_non_iid_5_4_zt'
run = api.run(url)

# Download history
history_df = run.history()

# %%
history_df
# Out:
#      _step      _runtime  centralized_accuracy    _timestamp  \
# 0        0    221.274873                0.0135  1.748817e+09
# 1        1    344.466857                0.0266  1.748817e+09
# 2        2    466.105809                0.0315  1.748818e+09
# 3        3    587.291544                0.0456  1.748818e+09
# 4        4    707.549367                0.0516  1.748818e+09
# ..     ...           ...                   ...           ...
# 146    146  18311.880460                0.5373  1.748835e+09
# 147    147  18438.321414                0.5406  1.748836e+09
# 148    148  18564.815723                0.5374  1.748836e+09
# 149    149  18691.526250                0.5569  1.748836e+09
# 150    150  18768.536397                0.5531  1.748836e+09
#
#      centralized_eval_loss  decentralized_avg_eval_loss  \
# 0                 6.539541                          NaN
# 1                 5.634396                     5.425895
# 2                 5.173844                     5.174538
# 3                 5.126227                     4.879901
# 4                 4.884283                     5.082959
# ..                     ...                          ...
# 146               1.685846                     1.835570
# 147               1.662967                     1.782687
# 148               1.663284                     1.700849
# 149               1.606591                     1.715397
# 150               1.604290                     1.481456
#
#      decentralized_avg_train_accuracy  decentralized_avg_train_loss  \
# 0                                 NaN                           NaN
# 1                            0.879297                      0.367230
# 2                            0.823438                      0.487653
# 3                            0.854297                      0.411399
# 4                            0.890625                      0.343332
# ..                                ...                           ...
# 146                          0.948047                      0.137350
# 147                          0.963672                      0.124330
# 148                          0.965234                      0.091090
# 149                          0.958594                      0.117585
# 150                          0.980469                      0.057307
#
#      decentralized_avg_eval_accuracy
# 0                                NaN
# 1                              0.030
# 2                              0.018
# 3                              0.040
# 4                              0.034
# ..                               ...
# 146                            0.508
# 147                            0.485
# 148                            0.525
# 149                            0.513
# 150                            0.585
#
# [151 rows x 9 columns]

# %%
filtered_df = history_df[history_df['_step'] <= 130]
filtered_df
# Out:
#      _step      _runtime    _timestamp  decentralized_avg_eval_accuracy  \
# 0        0    127.386535  1.748793e+09                              NaN
# 1        1    242.675903  1.748794e+09                            0.024
# 2        2    357.751460  1.748794e+09                            0.028
# 3        3    475.085162  1.748794e+09                            0.047
# 4        4    592.894629  1.748794e+09                            0.086
# ..     ...           ...           ...                              ...
# 126    126  14831.642152  1.748808e+09                            0.652
# 127    127  14948.673434  1.748808e+09                            0.668
# 128    128  15064.277690  1.748808e+09                            0.673
# 129    129  15182.452330  1.748809e+09                            0.700
# 130    130  15301.126247  1.748809e+09                            0.686
#
#      centralized_eval_loss  decentralized_avg_eval_loss  \
# 0                 6.243601                          NaN
# 1                 4.858862                     4.837299
# 2                 4.581037                     4.574687
# 3                 4.383195                     4.358886
# 4                 4.203520                     4.171981
# ..                     ...                          ...
# 126               1.115620                     1.270541
# 127               1.111873                     1.119065
# 128               1.111301                     1.112375
# 129               1.107440                     1.017895
# 130               1.109334                     1.094740
#
#      decentralized_avg_train_accuracy  centralized_accuracy  \
# 0                                 NaN                0.0129
# 1                            0.067969                0.0189
# 2                            0.092188                0.0341
# 3                            0.120703                0.0549
# 4                            0.174219                0.0824
# ..                                ...                   ...
# 126                          0.826953                0.6760
# 127                          0.823047                0.6798
# 128                          0.827344                0.6797
# 129                          0.829297                0.6778
# 130                          0.829688                0.6790
#
#      decentralized_avg_train_loss
# 0                             NaN
# 1                        4.422504
# 2                        4.151117
# 3                        3.981209
# 4                        3.798962
# ..                            ...
# 126                      0.655980
# 127                      0.637368
# 128                      0.639893
# 129                      0.604354
# 130                      0.623319
#
# [131 rows x 9 columns]

# %%
# Keep only steps ≤ 150
# filtered_df = history_df[history_df['_step'] <= 130]
filtered_df = history_df

project_name='FL_Dino_CIFAR100_base_new_batchsize64'
name = 'FL_Dino_Baseline_non_iid_5_4'
# Start a new run
new_run = wandb.init(project=project_name, name=name,id=name)

# Re-log filtered data
for _, row in filtered_df.iterrows():
    # Remove internal W&B columns if present
    step=int(row['_step'])
    row = row.drop(labels=[col for col in row.index if col.startswith('_')], errors='ignore')
    print(step)
    print(row.to_dict())
    wandb.log(row.to_dict(), step=step)

new_run.finish()
# Out:
# creating run (0.0s)
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>C:\Users\ADMIN\Desktop\BACKUP\study\Italy\polito\classes\20242\deep learning\project\source_code\fl-g13\notebooks\wandb\run-20250602_201532-FL_Dino_Baseline_non_iid_5_4</code>
# Syncing run <strong><a href='https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64/runs/FL_Dino_Baseline_non_iid_5_4' target="_blank">FL_Dino_Baseline_non_iid_5_4</a></strong> to <a href='https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64' target="_blank">https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64</a>
#  View run at <a href='https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64/runs/FL_Dino_Baseline_non_iid_5_4' target="_blank">https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64/runs/FL_Dino_Baseline_non_iid_5_4</a>
# 0
# {'centralized_accuracy': 0.0135, 'centralized_eval_loss': 6.539541090639254, 'decentralized_avg_eval_loss': nan, 'decentralized_avg_train_accuracy': nan, 'decentralized_avg_train_loss': nan, 'decentralized_avg_eval_accuracy': nan}
# 1
# {'centralized_accuracy': 0.0266, 'centralized_eval_loss': 5.634395661826332, 'decentralized_avg_eval_loss': 5.4258949756622314, 'decentralized_avg_train_accuracy': 0.879296875, 'decentralized_avg_train_loss': 0.3672297019511461, 'decentralized_avg_eval_accuracy': 0.03}
# 2
# {'centralized_accuracy': 0.0315, 'centralized_eval_loss': 5.173844183595797, 'decentralized_avg_eval_loss': 5.1745375990867615, 'decentralized_avg_train_accuracy': 0.8234375, 'decentralized_avg_train_loss': 0.4876529682427645, 'decentralized_avg_eval_accuracy': 0.018}
# 3
# {'centralized_accuracy': 0.0456, 'centralized_eval_loss': 5.126227075680376, 'decentralized_avg_eval_loss': 4.879900670051574, 'decentralized_avg_train_accuracy': 0.854296875, 'decentralized_avg_train_loss': 0.4113992227241397, 'decentralized_avg_eval_accuracy': 0.04}
# 4
# {'centralized_accuracy': 0.0516, 'centralized_eval_loss': 4.884282695599638, 'decentralized_avg_eval_loss': 5.082959353923798, 'decentralized_avg_train_accuracy': 0.890625, 'decentralized_avg_train_loss': 0.34333222098648547, 'decentralized_avg_eval_accuracy': 0.034}
# 5
# {'centralized_accuracy': 0.0513, 'centralized_eval_loss': 5.001462878510594, 'decentralized_avg_eval_loss': 5.27367445230484, 'decentralized_avg_train_accuracy': 0.85078125, 'decentralized_avg_train_loss': 0.435264790430665, 'decentralized_avg_eval_accuracy': 0.026}
# 6
# {'centralized_accuracy': 0.0995, 'centralized_eval_loss': 4.738882310855122, 'decentralized_avg_eval_loss': 4.239155411720276, 'decentralized_avg_train_accuracy': 0.880078125, 'decentralized_avg_train_loss': 0.34784157332032917, 'decentralized_avg_eval_accuracy': 0.144}
# 7
# {'centralized_accuracy': 0.0633, 'centralized_eval_loss': 5.032531489198581, 'decentralized_avg_eval_loss': 4.972257578372956, 'decentralized_avg_train_accuracy': 0.859375, 'decentralized_avg_train_loss': 0.395509111136198, 'decentralized_avg_eval_accuracy': 0.075}
# 8
# {'centralized_accuracy': 0.0998, 'centralized_eval_loss': 4.445984286622117, 'decentralized_avg_eval_loss': 4.58772703409195, 'decentralized_avg_train_accuracy': 0.862890625, 'decentralized_avg_train_loss': 0.37641718350350856, 'decentralized_avg_eval_accuracy': 0.07}
# 9
# {'centralized_accuracy': 0.0916, 'centralized_eval_loss': 4.46344768886749, 'decentralized_avg_eval_loss': 4.676673650741577, 'decentralized_avg_train_accuracy': 0.8765625, 'decentralized_avg_train_loss': 0.3693712897598743, 'decentralized_avg_eval_accuracy': 0.082}
# 10
# {'centralized_accuracy': 0.106, 'centralized_eval_loss': 4.321848742116374, 'decentralized_avg_eval_loss': 4.417600619792938, 'decentralized_avg_train_accuracy': 0.891796875, 'decentralized_avg_train_loss': 0.3173697615042329, 'decentralized_avg_eval_accuracy': 0.128}
# 11
# {'centralized_accuracy': 0.1267, 'centralized_eval_loss': 4.109381207261984, 'decentralized_avg_eval_loss': 4.262833654880524, 'decentralized_avg_train_accuracy': 0.8828125, 'decentralized_avg_train_loss': 0.3573386901989579, 'decentralized_avg_eval_accuracy': 0.052}
# 12
# {'centralized_accuracy': 0.1109, 'centralized_eval_loss': 4.266876374570707, 'decentralized_avg_eval_loss': 4.284083515405655, 'decentralized_avg_train_accuracy': 0.903515625, 'decentralized_avg_train_loss': 0.29501713877543806, 'decentralized_avg_eval_accuracy': 0.104}
# 13
# {'centralized_accuracy': 0.1174, 'centralized_eval_loss': 4.231737559595809, 'decentralized_avg_eval_loss': 3.5982088446617126, 'decentralized_avg_train_accuracy': 0.878515625, 'decentralized_avg_train_loss': 0.3381482856348157, 'decentralized_avg_eval_accuracy': 0.196}
# 14
# {'centralized_accuracy': 0.0908, 'centralized_eval_loss': 4.5403662939041185, 'decentralized_avg_eval_loss': 4.4490375280380245, 'decentralized_avg_train_accuracy': 0.89609375, 'decentralized_avg_train_loss': 0.29892891496419904, 'decentralized_avg_eval_accuracy': 0.105}
# 15
# {'centralized_accuracy': 0.1289, 'centralized_eval_loss': 4.125186191961026, 'decentralized_avg_eval_loss': 4.107582938671112, 'decentralized_avg_train_accuracy': 0.923828125, 'decentralized_avg_train_loss': 0.2500089921057224, 'decentralized_avg_eval_accuracy': 0.114}
# 16
# {'centralized_accuracy': 0.1859, 'centralized_eval_loss': 3.6478473957354267, 'decentralized_avg_eval_loss': 3.740675377845764, 'decentralized_avg_train_accuracy': 0.92265625, 'decentralized_avg_train_loss': 0.25233967062085866, 'decentralized_avg_eval_accuracy': 0.158}
# 17
# {'centralized_accuracy': 0.1177, 'centralized_eval_loss': 4.139940950436333, 'decentralized_avg_eval_loss': 4.461558198928833, 'decentralized_avg_train_accuracy': 0.89296875, 'decentralized_avg_train_loss': 0.29766138223931193, 'decentralized_avg_eval_accuracy': 0.106}
# 18
# {'centralized_accuracy': 0.1738, 'centralized_eval_loss': 3.869363323187295, 'decentralized_avg_eval_loss': 4.120924425125122, 'decentralized_avg_train_accuracy': 0.915234375, 'decentralized_avg_train_loss': 0.2531768006272614, 'decentralized_avg_eval_accuracy': 0.113}
# 19
# {'centralized_accuracy': 0.178, 'centralized_eval_loss': 3.735162416586099, 'decentralized_avg_eval_loss': 3.726710730791092, 'decentralized_avg_train_accuracy': 0.89765625, 'decentralized_avg_train_loss': 0.2895704098045826, 'decentralized_avg_eval_accuracy': 0.186}
# 20
# {'centralized_accuracy': 0.1906, 'centralized_eval_loss': 3.5446901869850036, 'decentralized_avg_eval_loss': 3.2648534297943117, 'decentralized_avg_train_accuracy': 0.902734375, 'decentralized_avg_train_loss': 0.27632723581045865, 'decentralized_avg_eval_accuracy': 0.212}
# 21
# {'centralized_accuracy': 0.181, 'centralized_eval_loss': 3.6984379847590536, 'decentralized_avg_eval_loss': 3.4828975915908815, 'decentralized_avg_train_accuracy': 0.90859375, 'decentralized_avg_train_loss': 0.2520110266283154, 'decentralized_avg_eval_accuracy': 0.205}
# 22
# {'centralized_accuracy': 0.1978, 'centralized_eval_loss': 3.5138325112315414, 'decentralized_avg_eval_loss': 3.31371847987175, 'decentralized_avg_train_accuracy': 0.898828125, 'decentralized_avg_train_loss': 0.286546934209764, 'decentralized_avg_eval_accuracy': 0.27}
# 23
# {'centralized_accuracy': 0.1989, 'centralized_eval_loss': 3.5647361788886807, 'decentralized_avg_eval_loss': 3.6622020959854127, 'decentralized_avg_train_accuracy': 0.9171875, 'decentralized_avg_train_loss': 0.23835095539689063, 'decentralized_avg_eval_accuracy': 0.204}
# 24
# {'centralized_accuracy': 0.212, 'centralized_eval_loss': 3.481077539273344, 'decentralized_avg_eval_loss': 3.217622008919716, 'decentralized_avg_train_accuracy': 0.925390625, 'decentralized_avg_train_loss': 0.2253172757104039, 'decentralized_avg_eval_accuracy': 0.249}
# 25
# {'centralized_accuracy': 0.2395, 'centralized_eval_loss': 3.3090333816723323, 'decentralized_avg_eval_loss': 2.990193098783493, 'decentralized_avg_train_accuracy': 0.93125, 'decentralized_avg_train_loss': 0.2016146954614669, 'decentralized_avg_eval_accuracy': 0.287}
# 26
# {'centralized_accuracy': 0.2815, 'centralized_eval_loss': 2.9818644786414246, 'decentralized_avg_eval_loss': 3.091521680355072, 'decentralized_avg_train_accuracy': 0.8953125, 'decentralized_avg_train_loss': 0.28466573916375637, 'decentralized_avg_eval_accuracy': 0.246}
# 27
# {'centralized_accuracy': 0.2602, 'centralized_eval_loss': 3.0873365973512206, 'decentralized_avg_eval_loss': 3.2842860877513886, 'decentralized_avg_train_accuracy': 0.91953125, 'decentralized_avg_train_loss': 0.23239142103120686, 'decentralized_avg_eval_accuracy': 0.213}
# 28
# {'centralized_accuracy': 0.2518, 'centralized_eval_loss': 3.234177158282588, 'decentralized_avg_eval_loss': 3.2554751098155976, 'decentralized_avg_train_accuracy': 0.91796875, 'decentralized_avg_train_loss': 0.23520390167832375, 'decentralized_avg_eval_accuracy': 0.232}
# 29
# {'centralized_accuracy': 0.2415, 'centralized_eval_loss': 3.2902050939992593, 'decentralized_avg_eval_loss': 3.4462411999702454, 'decentralized_avg_train_accuracy': 0.9328125, 'decentralized_avg_train_loss': 0.19022204354405403, 'decentralized_avg_eval_accuracy': 0.206}
# 30
# {'centralized_accuracy': 0.2426, 'centralized_eval_loss': 3.3328830472196636, 'decentralized_avg_eval_loss': 3.436683714389801, 'decentralized_avg_train_accuracy': 0.93125, 'decentralized_avg_train_loss': 0.21102771749719978, 'decentralized_avg_eval_accuracy': 0.207}
# 31
# {'centralized_accuracy': 0.2694, 'centralized_eval_loss': 3.1611296445036086, 'decentralized_avg_eval_loss': 3.3794737219810487, 'decentralized_avg_train_accuracy': 0.927734375, 'decentralized_avg_train_loss': 0.20218422012403608, 'decentralized_avg_eval_accuracy': 0.211}
# 32
# {'centralized_accuracy': 0.2693, 'centralized_eval_loss': 3.1348257201929064, 'decentralized_avg_eval_loss': 3.0653883635997774, 'decentralized_avg_train_accuracy': 0.923828125, 'decentralized_avg_train_loss': 0.21799912061542273, 'decentralized_avg_eval_accuracy': 0.3}
# 33
# {'centralized_accuracy': 0.2883, 'centralized_eval_loss': 2.9723351146466435, 'decentralized_avg_eval_loss': 3.2449889302253725, 'decentralized_avg_train_accuracy': 0.908984375, 'decentralized_avg_train_loss': 0.24318154398351907, 'decentralized_avg_eval_accuracy': 0.227}
# 34
# {'centralized_accuracy': 0.2866, 'centralized_eval_loss': 2.9394662601117507, 'decentralized_avg_eval_loss': 2.9397022306919096, 'decentralized_avg_train_accuracy': 0.9296875, 'decentralized_avg_train_loss': 0.1916494003497064, 'decentralized_avg_eval_accuracy': 0.3}
# 35
# {'centralized_accuracy': 0.2971, 'centralized_eval_loss': 2.9604558662865488, 'decentralized_avg_eval_loss': 3.0509929299354552, 'decentralized_avg_train_accuracy': 0.924609375, 'decentralized_avg_train_loss': 0.1991644522640854, 'decentralized_avg_eval_accuracy': 0.26}
# 36
# {'centralized_accuracy': 0.2999, 'centralized_eval_loss': 2.988943449224527, 'decentralized_avg_eval_loss': 3.0185333669185637, 'decentralized_avg_train_accuracy': 0.92421875, 'decentralized_avg_train_loss': 0.2124884135555476, 'decentralized_avg_eval_accuracy': 0.262}
# 37
# {'centralized_accuracy': 0.3218, 'centralized_eval_loss': 2.707339927792168, 'decentralized_avg_eval_loss': 3.06961413025856, 'decentralized_avg_train_accuracy': 0.926953125, 'decentralized_avg_train_loss': 0.1863610564963892, 'decentralized_avg_eval_accuracy': 0.235}
# 38
# {'centralized_accuracy': 0.2892, 'centralized_eval_loss': 2.9656194429428053, 'decentralized_avg_eval_loss': 2.774073576927185, 'decentralized_avg_train_accuracy': 0.930078125, 'decentralized_avg_train_loss': 0.18673339998349547, 'decentralized_avg_eval_accuracy': 0.337}
# 39
# {'centralized_accuracy': 0.3187, 'centralized_eval_loss': 2.8742429227493824, 'decentralized_avg_eval_loss': 2.9533241033554076, 'decentralized_avg_train_accuracy': 0.919921875, 'decentralized_avg_train_loss': 0.21456484282389282, 'decentralized_avg_eval_accuracy': 0.31}
# 40
# {'centralized_accuracy': 0.3439, 'centralized_eval_loss': 2.5893511265611497, 'decentralized_avg_eval_loss': 2.5753970384597777, 'decentralized_avg_train_accuracy': 0.924609375, 'decentralized_avg_train_loss': 0.21775017087347806, 'decentralized_avg_eval_accuracy': 0.362}
# 41
# {'centralized_accuracy': 0.2598, 'centralized_eval_loss': 3.0541035420597553, 'decentralized_avg_eval_loss': 3.2134230971336364, 'decentralized_avg_train_accuracy': 0.910546875, 'decentralized_avg_train_loss': 0.24124408643692732, 'decentralized_avg_eval_accuracy': 0.221}
# 42
# {'centralized_accuracy': 0.314, 'centralized_eval_loss': 2.841749470454816, 'decentralized_avg_eval_loss': 2.909126341342926, 'decentralized_avg_train_accuracy': 0.9515625, 'decentralized_avg_train_loss': 0.13698144026566297, 'decentralized_avg_eval_accuracy': 0.296}
# 43
# {'centralized_accuracy': 0.3306, 'centralized_eval_loss': 2.7681245601977023, 'decentralized_avg_eval_loss': 2.4448354661464693, 'decentralized_avg_train_accuracy': 0.934375, 'decentralized_avg_train_loss': 0.18237039186060428, 'decentralized_avg_eval_accuracy': 0.384}
# 44
# {'centralized_accuracy': 0.3704, 'centralized_eval_loss': 2.601236433266832, 'decentralized_avg_eval_loss': 2.30655038356781, 'decentralized_avg_train_accuracy': 0.926953125, 'decentralized_avg_train_loss': 0.20885731633752586, 'decentralized_avg_eval_accuracy': 0.428}
# 45
# {'centralized_accuracy': 0.336, 'centralized_eval_loss': 2.6834688868385532, 'decentralized_avg_eval_loss': 2.605452072620392, 'decentralized_avg_train_accuracy': 0.944140625, 'decentralized_avg_train_loss': 0.1639795689843595, 'decentralized_avg_eval_accuracy': 0.32}
# 46
# {'centralized_accuracy': 0.3689, 'centralized_eval_loss': 2.4836407301905816, 'decentralized_avg_eval_loss': 2.3615848243236544, 'decentralized_avg_train_accuracy': 0.939453125, 'decentralized_avg_train_loss': 0.17247564722783865, 'decentralized_avg_eval_accuracy': 0.411}
# 47
# {'centralized_accuracy': 0.376, 'centralized_eval_loss': 2.465917391137193, 'decentralized_avg_eval_loss': 2.810180675983429, 'decentralized_avg_train_accuracy': 0.938671875, 'decentralized_avg_train_loss': 0.17055961708538234, 'decentralized_avg_eval_accuracy': 0.302}
# 48
# {'centralized_accuracy': 0.381, 'centralized_eval_loss': 2.4234347019713525, 'decentralized_avg_eval_loss': 2.6015436470508577, 'decentralized_avg_train_accuracy': 0.950390625, 'decentralized_avg_train_loss': 0.14106558663770558, 'decentralized_avg_eval_accuracy': 0.348}
# 49
# {'centralized_accuracy': 0.3737, 'centralized_eval_loss': 2.505160800565165, 'decentralized_avg_eval_loss': 2.6802103757858275, 'decentralized_avg_train_accuracy': 0.93671875, 'decentralized_avg_train_loss': 0.18767921561375261, 'decentralized_avg_eval_accuracy': 0.354}
# 50
# {'centralized_accuracy': 0.3633, 'centralized_eval_loss': 2.5199613765405773, 'decentralized_avg_eval_loss': 2.2875158548355103, 'decentralized_avg_train_accuracy': 0.953515625, 'decentralized_avg_train_loss': 0.1326735318871215, 'decentralized_avg_eval_accuracy': 0.38}
# 51
# {'centralized_accuracy': 0.3886, 'centralized_eval_loss': 2.3988398972410745, 'decentralized_avg_eval_loss': 2.412734740972519, 'decentralized_avg_train_accuracy': 0.943359375, 'decentralized_avg_train_loss': 0.16302954368293285, 'decentralized_avg_eval_accuracy': 0.363}
# 52
# {'centralized_accuracy': 0.4146, 'centralized_eval_loss': 2.2558569946228126, 'decentralized_avg_eval_loss': 2.0772977471351624, 'decentralized_avg_train_accuracy': 0.939453125, 'decentralized_avg_train_loss': 0.17227988557424395, 'decentralized_avg_eval_accuracy': 0.451}
# 53
# {'centralized_accuracy': 0.3967, 'centralized_eval_loss': 2.317956301731804, 'decentralized_avg_eval_loss': 2.1391882359981538, 'decentralized_avg_train_accuracy': 0.93203125, 'decentralized_avg_train_loss': 0.18259813953191043, 'decentralized_avg_eval_accuracy': 0.442}
# 54
# {'centralized_accuracy': 0.3745, 'centralized_eval_loss': 2.4674091628565193, 'decentralized_avg_eval_loss': 2.889207774400711, 'decentralized_avg_train_accuracy': 0.948828125, 'decentralized_avg_train_loss': 0.13555581690743565, 'decentralized_avg_eval_accuracy': 0.293}
# 55
# {'centralized_accuracy': 0.3931, 'centralized_eval_loss': 2.4240307190928596, 'decentralized_avg_eval_loss': 2.407348644733429, 'decentralized_avg_train_accuracy': 0.948046875, 'decentralized_avg_train_loss': 0.14289505123160778, 'decentralized_avg_eval_accuracy': 0.406}
# 56
# {'centralized_accuracy': 0.4127, 'centralized_eval_loss': 2.2562823093737276, 'decentralized_avg_eval_loss': 2.2557578086853027, 'decentralized_avg_train_accuracy': 0.9390625, 'decentralized_avg_train_loss': 0.1676952158100903, 'decentralized_avg_eval_accuracy': 0.401}
# 57
# {'centralized_accuracy': 0.3972, 'centralized_eval_loss': 2.400903815659471, 'decentralized_avg_eval_loss': 2.1402315139770507, 'decentralized_avg_train_accuracy': 0.945703125, 'decentralized_avg_train_loss': 0.14979955945163964, 'decentralized_avg_eval_accuracy': 0.437}
# 58
# {'centralized_accuracy': 0.4156, 'centralized_eval_loss': 2.3022690055469353, 'decentralized_avg_eval_loss': 2.111705166101456, 'decentralized_avg_train_accuracy': 0.92421875, 'decentralized_avg_train_loss': 0.21103291865438223, 'decentralized_avg_eval_accuracy': 0.461}
# 59
# {'centralized_accuracy': 0.4212, 'centralized_eval_loss': 2.205192301600886, 'decentralized_avg_eval_loss': 1.9686588168144226, 'decentralized_avg_train_accuracy': 0.94140625, 'decentralized_avg_train_loss': 0.1709377302788198, 'decentralized_avg_eval_accuracy': 0.49}
# 60
# {'centralized_accuracy': 0.4133, 'centralized_eval_loss': 2.2154009909675527, 'decentralized_avg_eval_loss': 2.037637013196945, 'decentralized_avg_train_accuracy': 0.951953125, 'decentralized_avg_train_loss': 0.13621900603175163, 'decentralized_avg_eval_accuracy': 0.435}
# 61
# {'centralized_accuracy': 0.3906, 'centralized_eval_loss': 2.316273319073759, 'decentralized_avg_eval_loss': 2.150387924909592, 'decentralized_avg_train_accuracy': 0.958203125, 'decentralized_avg_train_loss': 0.12775341160595416, 'decentralized_avg_eval_accuracy': 0.424}
# 62
# {'centralized_accuracy': 0.4119, 'centralized_eval_loss': 2.3050118300099722, 'decentralized_avg_eval_loss': 2.264865851402283, 'decentralized_avg_train_accuracy': 0.935546875, 'decentralized_avg_train_loss': 0.1928412139415741, 'decentralized_avg_eval_accuracy': 0.423}
# 63
# {'centralized_accuracy': 0.4326, 'centralized_eval_loss': 2.185990622249274, 'decentralized_avg_eval_loss': 2.3259704947471618, 'decentralized_avg_train_accuracy': 0.94921875, 'decentralized_avg_train_loss': 0.14449481768533587, 'decentralized_avg_eval_accuracy': 0.408}
# 64
# {'centralized_accuracy': 0.4015, 'centralized_eval_loss': 2.3298675492167855, 'decentralized_avg_eval_loss': 2.4779476046562197, 'decentralized_avg_train_accuracy': 0.955078125, 'decentralized_avg_train_loss': 0.11598084054421634, 'decentralized_avg_eval_accuracy': 0.366}
# 65
# {'centralized_accuracy': 0.4277, 'centralized_eval_loss': 2.303552230706992, 'decentralized_avg_eval_loss': 2.38648744225502, 'decentralized_avg_train_accuracy': 0.959765625, 'decentralized_avg_train_loss': 0.12820501471869647, 'decentralized_avg_eval_accuracy': 0.402}
# 66
# {'centralized_accuracy': 0.4136, 'centralized_eval_loss': 2.2594358509721846, 'decentralized_avg_eval_loss': 1.9685877799987792, 'decentralized_avg_train_accuracy': 0.9375, 'decentralized_avg_train_loss': 0.17343471867498012, 'decentralized_avg_eval_accuracy': 0.485}
# 67
# {'centralized_accuracy': 0.4145, 'centralized_eval_loss': 2.2472568133387703, 'decentralized_avg_eval_loss': 2.5011428773403166, 'decentralized_avg_train_accuracy': 0.95546875, 'decentralized_avg_train_loss': 0.13838634006679057, 'decentralized_avg_eval_accuracy': 0.354}
# 68
# {'centralized_accuracy': 0.4435, 'centralized_eval_loss': 2.1001408202960468, 'decentralized_avg_eval_loss': 2.1797036111354826, 'decentralized_avg_train_accuracy': 0.941015625, 'decentralized_avg_train_loss': 0.15812830878421663, 'decentralized_avg_eval_accuracy': 0.444}
# 69
# {'centralized_accuracy': 0.4333, 'centralized_eval_loss': 2.1798044903971516, 'decentralized_avg_eval_loss': 2.3001724004745485, 'decentralized_avg_train_accuracy': 0.959375, 'decentralized_avg_train_loss': 0.12103444619569928, 'decentralized_avg_eval_accuracy': 0.409}
# 70
# {'centralized_accuracy': 0.4383, 'centralized_eval_loss': 2.1386618522790295, 'decentralized_avg_eval_loss': 2.100771778821945, 'decentralized_avg_train_accuracy': 0.9546875, 'decentralized_avg_train_loss': 0.13918042345903814, 'decentralized_avg_eval_accuracy': 0.437}
# 71
# {'centralized_accuracy': 0.4231, 'centralized_eval_loss': 2.221340142119045, 'decentralized_avg_eval_loss': 2.001322165131569, 'decentralized_avg_train_accuracy': 0.95546875, 'decentralized_avg_train_loss': 0.11502410301472991, 'decentralized_avg_eval_accuracy': 0.491}
# 72
# {'centralized_accuracy': 0.4427, 'centralized_eval_loss': 2.109470500351903, 'decentralized_avg_eval_loss': 2.178465610742569, 'decentralized_avg_train_accuracy': 0.938671875, 'decentralized_avg_train_loss': 0.17068849885836243, 'decentralized_avg_eval_accuracy': 0.43}
# 73
# {'centralized_accuracy': 0.4563, 'centralized_eval_loss': 2.0670338796731382, 'decentralized_avg_eval_loss': 1.6006944328546524, 'decentralized_avg_train_accuracy': 0.95390625, 'decentralized_avg_train_loss': 0.11672779265791178, 'decentralized_avg_eval_accuracy': 0.552}
# 74
# {'centralized_accuracy': 0.407, 'centralized_eval_loss': 2.2014286700909893, 'decentralized_avg_eval_loss': 2.260103940963745, 'decentralized_avg_train_accuracy': 0.946484375, 'decentralized_avg_train_loss': 0.14666392803192138, 'decentralized_avg_eval_accuracy': 0.364}
# 75
# {'centralized_accuracy': 0.4428, 'centralized_eval_loss': 2.127234149664736, 'decentralized_avg_eval_loss': 2.20800125002861, 'decentralized_avg_train_accuracy': 0.93359375, 'decentralized_avg_train_loss': 0.17846135436557234, 'decentralized_avg_eval_accuracy': 0.435}
# 76
# {'centralized_accuracy': 0.4343, 'centralized_eval_loss': 2.1785701143855865, 'decentralized_avg_eval_loss': 2.5784631252288817, 'decentralized_avg_train_accuracy': 0.95078125, 'decentralized_avg_train_loss': 0.12976490147411823, 'decentralized_avg_eval_accuracy': 0.337}
# 77
# {'centralized_accuracy': 0.431, 'centralized_eval_loss': 2.1660267663078185, 'decentralized_avg_eval_loss': 2.0599850535392763, 'decentralized_avg_train_accuracy': 0.959375, 'decentralized_avg_train_loss': 0.11663799034431577, 'decentralized_avg_eval_accuracy': 0.413}
# 78
# {'centralized_accuracy': 0.4406, 'centralized_eval_loss': 2.1388194896161745, 'decentralized_avg_eval_loss': 2.3053142070770263, 'decentralized_avg_train_accuracy': 0.9421875, 'decentralized_avg_train_loss': 0.15698475374374538, 'decentralized_avg_eval_accuracy': 0.385}
# 79
# {'centralized_accuracy': 0.4683, 'centralized_eval_loss': 2.031651865560026, 'decentralized_avg_eval_loss': 2.334585416316986, 'decentralized_avg_train_accuracy': 0.959765625, 'decentralized_avg_train_loss': 0.1201413935283199, 'decentralized_avg_eval_accuracy': 0.409}
# 80
# {'centralized_accuracy': 0.4534, 'centralized_eval_loss': 2.041288236078744, 'decentralized_avg_eval_loss': 1.987127912044525, 'decentralized_avg_train_accuracy': 0.94921875, 'decentralized_avg_train_loss': 0.13759513590484856, 'decentralized_avg_eval_accuracy': 0.461}
# 81
# {'centralized_accuracy': 0.4558, 'centralized_eval_loss': 2.0638902476801277, 'decentralized_avg_eval_loss': 1.8940056920051576, 'decentralized_avg_train_accuracy': 0.955078125, 'decentralized_avg_train_loss': 0.13468246010597795, 'decentralized_avg_eval_accuracy': 0.495}
# 82
# {'centralized_accuracy': 0.4375, 'centralized_eval_loss': 2.1527638366808906, 'decentralized_avg_eval_loss': 2.368002325296402, 'decentralized_avg_train_accuracy': 0.930859375, 'decentralized_avg_train_loss': 0.18953713588416576, 'decentralized_avg_eval_accuracy': 0.439}
# 83
# {'centralized_accuracy': 0.4505, 'centralized_eval_loss': 2.060168543372291, 'decentralized_avg_eval_loss': 2.096402168273926, 'decentralized_avg_train_accuracy': 0.9453125, 'decentralized_avg_train_loss': 0.15107588651590048, 'decentralized_avg_eval_accuracy': 0.414}
# 84
# {'centralized_accuracy': 0.4653, 'centralized_eval_loss': 1.9685375492412822, 'decentralized_avg_eval_loss': 1.9815607786178588, 'decentralized_avg_train_accuracy': 0.953125, 'decentralized_avg_train_loss': 0.14150815093889832, 'decentralized_avg_eval_accuracy': 0.443}
# 85
# {'centralized_accuracy': 0.4946, 'centralized_eval_loss': 1.8682601665155576, 'decentralized_avg_eval_loss': 1.9776357799768447, 'decentralized_avg_train_accuracy': 0.96328125, 'decentralized_avg_train_loss': 0.10417730147019029, 'decentralized_avg_eval_accuracy': 0.46}
# 86
# {'centralized_accuracy': 0.4783, 'centralized_eval_loss': 1.9380691493281161, 'decentralized_avg_eval_loss': 1.8399058640003205, 'decentralized_avg_train_accuracy': 0.95859375, 'decentralized_avg_train_loss': 0.1134847954614088, 'decentralized_avg_eval_accuracy': 0.492}
# 87
# {'centralized_accuracy': 0.482, 'centralized_eval_loss': 1.9071961620364326, 'decentralized_avg_eval_loss': 2.065840256214142, 'decentralized_avg_train_accuracy': 0.9453125, 'decentralized_avg_train_loss': 0.13995632878504694, 'decentralized_avg_eval_accuracy': 0.453}
# 88
# {'centralized_accuracy': 0.4692, 'centralized_eval_loss': 2.0512045511422445, 'decentralized_avg_eval_loss': 2.1710090160369875, 'decentralized_avg_train_accuracy': 0.958984375, 'decentralized_avg_train_loss': 0.11276284893974661, 'decentralized_avg_eval_accuracy': 0.437}
# 89
# {'centralized_accuracy': 0.4483, 'centralized_eval_loss': 2.113485560630457, 'decentralized_avg_eval_loss': 2.3001775324344633, 'decentralized_avg_train_accuracy': 0.9421875, 'decentralized_avg_train_loss': 0.15866971223149448, 'decentralized_avg_eval_accuracy': 0.385}
# 90
# {'centralized_accuracy': 0.4494, 'centralized_eval_loss': 2.140281307430694, 'decentralized_avg_eval_loss': 2.135754632949829, 'decentralized_avg_train_accuracy': 0.93359375, 'decentralized_avg_train_loss': 0.1854093110654503, 'decentralized_avg_eval_accuracy': 0.454}
# 91
# {'centralized_accuracy': 0.4511, 'centralized_eval_loss': 2.079700540429868, 'decentralized_avg_eval_loss': 1.9905981570482254, 'decentralized_avg_train_accuracy': 0.95546875, 'decentralized_avg_train_loss': 0.1343702724436298, 'decentralized_avg_eval_accuracy': 0.499}
# 92
# {'centralized_accuracy': 0.4747, 'centralized_eval_loss': 1.9280934200500146, 'decentralized_avg_eval_loss': 2.175689786672592, 'decentralized_avg_train_accuracy': 0.950390625, 'decentralized_avg_train_loss': 0.12988717562984675, 'decentralized_avg_eval_accuracy': 0.402}
# 93
# {'centralized_accuracy': 0.4521, 'centralized_eval_loss': 1.9969842521527323, 'decentralized_avg_eval_loss': 1.7475400775671006, 'decentralized_avg_train_accuracy': 0.96015625, 'decentralized_avg_train_loss': 0.10802213968709111, 'decentralized_avg_eval_accuracy': 0.519}
# 94
# {'centralized_accuracy': 0.4571, 'centralized_eval_loss': 2.0597975829157966, 'decentralized_avg_eval_loss': 1.798081511259079, 'decentralized_avg_train_accuracy': 0.9484375, 'decentralized_avg_train_loss': 0.14448398924432695, 'decentralized_avg_eval_accuracy': 0.531}
# 95
# {'centralized_accuracy': 0.4787, 'centralized_eval_loss': 1.9129160448385123, 'decentralized_avg_eval_loss': 2.0740673363208773, 'decentralized_avg_train_accuracy': 0.946875, 'decentralized_avg_train_loss': 0.14444895167835056, 'decentralized_avg_eval_accuracy': 0.451}
# 96
# {'centralized_accuracy': 0.4927, 'centralized_eval_loss': 1.9205376755315275, 'decentralized_avg_eval_loss': 1.8564825624227523, 'decentralized_avg_train_accuracy': 0.9515625, 'decentralized_avg_train_loss': 0.13915099608711898, 'decentralized_avg_eval_accuracy': 0.471}
# 97
# {'centralized_accuracy': 0.4852, 'centralized_eval_loss': 1.9151655304165314, 'decentralized_avg_eval_loss': 2.0265551149845122, 'decentralized_avg_train_accuracy': 0.96171875, 'decentralized_avg_train_loss': 0.10930598904378712, 'decentralized_avg_eval_accuracy': 0.441}
# 98
# {'centralized_accuracy': 0.5031, 'centralized_eval_loss': 1.832889228773574, 'decentralized_avg_eval_loss': 1.8709045588970183, 'decentralized_avg_train_accuracy': 0.952734375, 'decentralized_avg_train_loss': 0.12734460970386863, 'decentralized_avg_eval_accuracy': 0.505}
# 99
# {'centralized_accuracy': 0.4695, 'centralized_eval_loss': 1.9782939111462796, 'decentralized_avg_eval_loss': 1.9504497051239014, 'decentralized_avg_train_accuracy': 0.960546875, 'decentralized_avg_train_loss': 0.10933799570193514, 'decentralized_avg_eval_accuracy': 0.462}
# 100
# {'centralized_accuracy': 0.4835, 'centralized_eval_loss': 1.916332301430809, 'decentralized_avg_eval_loss': 1.8385708689689637, 'decentralized_avg_train_accuracy': 0.955859375, 'decentralized_avg_train_loss': 0.12272878964431584, 'decentralized_avg_eval_accuracy': 0.498}
# 101
# {'centralized_accuracy': 0.4767, 'centralized_eval_loss': 2.011389554118196, 'decentralized_avg_eval_loss': 2.257302004098892, 'decentralized_avg_train_accuracy': 0.963671875, 'decentralized_avg_train_loss': 0.10673179989680648, 'decentralized_avg_eval_accuracy': 0.435}
# 102
# {'centralized_accuracy': 0.4873, 'centralized_eval_loss': 1.9268129778365357, 'decentralized_avg_eval_loss': 2.3000993847846987, 'decentralized_avg_train_accuracy': 0.956640625, 'decentralized_avg_train_loss': 0.11609301967546344, 'decentralized_avg_eval_accuracy': 0.432}
# 103
# {'centralized_accuracy': 0.4923, 'centralized_eval_loss': 1.899818954376367, 'decentralized_avg_eval_loss': 2.2586089372634888, 'decentralized_avg_train_accuracy': 0.970703125, 'decentralized_avg_train_loss': 0.07953756275819615, 'decentralized_avg_eval_accuracy': 0.416}
# 104
# {'centralized_accuracy': 0.4621, 'centralized_eval_loss': 2.048282484276988, 'decentralized_avg_eval_loss': 2.1947759360075, 'decentralized_avg_train_accuracy': 0.96328125, 'decentralized_avg_train_loss': 0.10024993564002216, 'decentralized_avg_eval_accuracy': 0.448}
# 105
# {'centralized_accuracy': 0.4778, 'centralized_eval_loss': 1.9825499286285986, 'decentralized_avg_eval_loss': 2.0881100714206697, 'decentralized_avg_train_accuracy': 0.960546875, 'decentralized_avg_train_loss': 0.11851913585560396, 'decentralized_avg_eval_accuracy': 0.449}
# 106
# {'centralized_accuracy': 0.4905, 'centralized_eval_loss': 1.8901460349750214, 'decentralized_avg_eval_loss': 1.9368418514728547, 'decentralized_avg_train_accuracy': 0.96015625, 'decentralized_avg_train_loss': 0.12362245923141017, 'decentralized_avg_eval_accuracy': 0.478}
# 107
# {'centralized_accuracy': 0.5075, 'centralized_eval_loss': 1.8128447075621388, 'decentralized_avg_eval_loss': 2.2170087516307833, 'decentralized_avg_train_accuracy': 0.93359375, 'decentralized_avg_train_loss': 0.1905351785477251, 'decentralized_avg_eval_accuracy': 0.404}
# 108
# {'centralized_accuracy': 0.4938, 'centralized_eval_loss': 1.9122753859328006, 'decentralized_avg_eval_loss': 2.1851221680641175, 'decentralized_avg_train_accuracy': 0.975390625, 'decentralized_avg_train_loss': 0.07519399393349886, 'decentralized_avg_eval_accuracy': 0.399}
# 109
# {'centralized_accuracy': 0.4867, 'centralized_eval_loss': 1.9412213160207097, 'decentralized_avg_eval_loss': 2.1869339406490327, 'decentralized_avg_train_accuracy': 0.9609375, 'decentralized_avg_train_loss': 0.11492701240349561, 'decentralized_avg_eval_accuracy': 0.432}
# 110
# {'centralized_accuracy': 0.5132, 'centralized_eval_loss': 1.7739323924143855, 'decentralized_avg_eval_loss': 1.629099604487419, 'decentralized_avg_train_accuracy': 0.959765625, 'decentralized_avg_train_loss': 0.11678517695982009, 'decentralized_avg_eval_accuracy': 0.545}
# 111
# {'centralized_accuracy': 0.5167, 'centralized_eval_loss': 1.8199845461037973, 'decentralized_avg_eval_loss': 2.0103189647197723, 'decentralized_avg_train_accuracy': 0.957421875, 'decentralized_avg_train_loss': 0.11591132367029786, 'decentralized_avg_eval_accuracy': 0.461}
# 112
# {'centralized_accuracy': 0.5104, 'centralized_eval_loss': 1.8261452871389663, 'decentralized_avg_eval_loss': 2.142273685336113, 'decentralized_avg_train_accuracy': 0.962890625, 'decentralized_avg_train_loss': 0.11078523157630116, 'decentralized_avg_eval_accuracy': 0.456}
# 113
# {'centralized_accuracy': 0.494, 'centralized_eval_loss': 1.9147298042766583, 'decentralized_avg_eval_loss': 1.8577262252569198, 'decentralized_avg_train_accuracy': 0.946875, 'decentralized_avg_train_loss': 0.154187420476228, 'decentralized_avg_eval_accuracy': 0.512}
# 114
# {'centralized_accuracy': 0.4822, 'centralized_eval_loss': 1.9438849413356842, 'decentralized_avg_eval_loss': 1.9803994357585908, 'decentralized_avg_train_accuracy': 0.9671875, 'decentralized_avg_train_loss': 0.08635520115494728, 'decentralized_avg_eval_accuracy': 0.464}
# 115
# {'centralized_accuracy': 0.4964, 'centralized_eval_loss': 1.8746130674030073, 'decentralized_avg_eval_loss': 1.8276339769363403, 'decentralized_avg_train_accuracy': 0.94140625, 'decentralized_avg_train_loss': 0.1710295892204158, 'decentralized_avg_eval_accuracy': 0.481}
# 116
# {'centralized_accuracy': 0.5146, 'centralized_eval_loss': 1.8023027558677114, 'decentralized_avg_eval_loss': 2.246486264467239, 'decentralized_avg_train_accuracy': 0.971484375, 'decentralized_avg_train_loss': 0.08471903265453876, 'decentralized_avg_eval_accuracy': 0.419}
# 117
# {'centralized_accuracy': 0.5098, 'centralized_eval_loss': 1.7693301126979792, 'decentralized_avg_eval_loss': 1.7014176726341248, 'decentralized_avg_train_accuracy': 0.95859375, 'decentralized_avg_train_loss': 0.11923053539358079, 'decentralized_avg_eval_accuracy': 0.513}
# 118
# {'centralized_accuracy': 0.52, 'centralized_eval_loss': 1.7340036162172263, 'decentralized_avg_eval_loss': 1.7486920177936554, 'decentralized_avg_train_accuracy': 0.936328125, 'decentralized_avg_train_loss': 0.17204049681313335, 'decentralized_avg_eval_accuracy': 0.513}
# 119
# {'centralized_accuracy': 0.5147, 'centralized_eval_loss': 1.7682337361021925, 'decentralized_avg_eval_loss': 1.8796648889780045, 'decentralized_avg_train_accuracy': 0.979296875, 'decentralized_avg_train_loss': 0.06785391829907894, 'decentralized_avg_eval_accuracy': 0.487}
# 120
# {'centralized_accuracy': 0.5137, 'centralized_eval_loss': 1.7906350261106279, 'decentralized_avg_eval_loss': 1.8043219596147537, 'decentralized_avg_train_accuracy': 0.956640625, 'decentralized_avg_train_loss': 0.11771272928453982, 'decentralized_avg_eval_accuracy': 0.509}
# 121
# {'centralized_accuracy': 0.5183, 'centralized_eval_loss': 1.738397157992037, 'decentralized_avg_eval_loss': 1.877493155002594, 'decentralized_avg_train_accuracy': 0.969140625, 'decentralized_avg_train_loss': 0.083920212299563, 'decentralized_avg_eval_accuracy': 0.493}
# 122
# {'centralized_accuracy': 0.5247, 'centralized_eval_loss': 1.6870200154118644, 'decentralized_avg_eval_loss': 1.7560161024332046, 'decentralized_avg_train_accuracy': 0.962109375, 'decentralized_avg_train_loss': 0.11223220429383218, 'decentralized_avg_eval_accuracy': 0.51}
# 123
# {'centralized_accuracy': 0.516, 'centralized_eval_loss': 1.7800481883100807, 'decentralized_avg_eval_loss': 2.0067979395389557, 'decentralized_avg_train_accuracy': 0.9671875, 'decentralized_avg_train_loss': 0.09537726435810327, 'decentralized_avg_eval_accuracy': 0.456}
# 124
# {'centralized_accuracy': 0.5213, 'centralized_eval_loss': 1.7298940092610855, 'decentralized_avg_eval_loss': 1.4556778609752654, 'decentralized_avg_train_accuracy': 0.975, 'decentralized_avg_train_loss': 0.07934424672275782, 'decentralized_avg_eval_accuracy': 0.592}
# 125
# {'centralized_accuracy': 0.4682, 'centralized_eval_loss': 2.020181452504362, 'decentralized_avg_eval_loss': 2.176010873913765, 'decentralized_avg_train_accuracy': 0.971875, 'decentralized_avg_train_loss': 0.0765153203101363, 'decentralized_avg_eval_accuracy': 0.46}
# 126
# {'centralized_accuracy': 0.5163, 'centralized_eval_loss': 1.777924605832694, 'decentralized_avg_eval_loss': 1.9686675190925598, 'decentralized_avg_train_accuracy': 0.97265625, 'decentralized_avg_train_loss': 0.07590931985760108, 'decentralized_avg_eval_accuracy': 0.477}
# 127
# {'centralized_accuracy': 0.5016, 'centralized_eval_loss': 1.858471339312605, 'decentralized_avg_eval_loss': 1.8132965058088302, 'decentralized_avg_train_accuracy': 0.970703125, 'decentralized_avg_train_loss': 0.08112965093459934, 'decentralized_avg_eval_accuracy': 0.511}
# 128
# {'centralized_accuracy': 0.5152, 'centralized_eval_loss': 1.799889386842807, 'decentralized_avg_eval_loss': 1.7191735088825226, 'decentralized_avg_train_accuracy': 0.96015625, 'decentralized_avg_train_loss': 0.10686905160546303, 'decentralized_avg_eval_accuracy': 0.505}
# 129
# {'centralized_accuracy': 0.4942, 'centralized_eval_loss': 1.8812879758140149, 'decentralized_avg_eval_loss': 2.2056002974510194, 'decentralized_avg_train_accuracy': 0.968359375, 'decentralized_avg_train_loss': 0.09888657280243933, 'decentralized_avg_eval_accuracy': 0.406}
# 130
# {'centralized_accuracy': 0.4713, 'centralized_eval_loss': 1.9651280175001857, 'decentralized_avg_eval_loss': 2.1034273892641067, 'decentralized_avg_train_accuracy': 0.966015625, 'decentralized_avg_train_loss': 0.09748895096126944, 'decentralized_avg_eval_accuracy': 0.441}
# 131
# {'centralized_accuracy': 0.5117, 'centralized_eval_loss': 1.7669294379389704, 'decentralized_avg_eval_loss': 1.6534004300832748, 'decentralized_avg_train_accuracy': 0.962890625, 'decentralized_avg_train_loss': 0.10811247704550624, 'decentralized_avg_eval_accuracy': 0.539}
# 132
# {'centralized_accuracy': 0.5104, 'centralized_eval_loss': 1.8103340479512564, 'decentralized_avg_eval_loss': 1.8428514331579209, 'decentralized_avg_train_accuracy': 0.97265625, 'decentralized_avg_train_loss': 0.09531299674417823, 'decentralized_avg_eval_accuracy': 0.527}
# 133
# {'centralized_accuracy': 0.5131, 'centralized_eval_loss': 1.7789549330552927, 'decentralized_avg_eval_loss': 1.588735008239746, 'decentralized_avg_train_accuracy': 0.9578125, 'decentralized_avg_train_loss': 0.11117659413721412, 'decentralized_avg_eval_accuracy': 0.557}
# 134
# {'centralized_accuracy': 0.5185, 'centralized_eval_loss': 1.7657919095727963, 'decentralized_avg_eval_loss': 1.8758283317089082, 'decentralized_avg_train_accuracy': 0.96328125, 'decentralized_avg_train_loss': 0.1045058581221383, 'decentralized_avg_eval_accuracy': 0.493}
# 135
# {'centralized_accuracy': 0.5072, 'centralized_eval_loss': 1.7952339215019641, 'decentralized_avg_eval_loss': 2.073855531215668, 'decentralized_avg_train_accuracy': 0.97109375, 'decentralized_avg_train_loss': 0.08974929116666316, 'decentralized_avg_eval_accuracy': 0.433}
# 136
# {'centralized_accuracy': 0.506, 'centralized_eval_loss': 1.8291485164873897, 'decentralized_avg_eval_loss': 2.0441767036914826, 'decentralized_avg_train_accuracy': 0.96171875, 'decentralized_avg_train_loss': 0.11060413718223572, 'decentralized_avg_eval_accuracy': 0.468}
# 137
# {'centralized_accuracy': 0.5122, 'centralized_eval_loss': 1.7806548518113816, 'decentralized_avg_eval_loss': 1.8271675735712052, 'decentralized_avg_train_accuracy': 0.96484375, 'decentralized_avg_train_loss': 0.10464260606095195, 'decentralized_avg_eval_accuracy': 0.512}
# 138
# {'centralized_accuracy': 0.512, 'centralized_eval_loss': 1.7788435862468073, 'decentralized_avg_eval_loss': 1.9469103991985321, 'decentralized_avg_train_accuracy': 0.957421875, 'decentralized_avg_train_loss': 0.11854729829356074, 'decentralized_avg_eval_accuracy': 0.478}
# 139
# {'centralized_accuracy': 0.5237, 'centralized_eval_loss': 1.789782753958108, 'decentralized_avg_eval_loss': 1.9629487633705138, 'decentralized_avg_train_accuracy': 0.96953125, 'decentralized_avg_train_loss': 0.09239267552038655, 'decentralized_avg_eval_accuracy': 0.461}
# 140
# {'centralized_accuracy': 0.5191, 'centralized_eval_loss': 1.7527024900189603, 'decentralized_avg_eval_loss': 1.623646503686905, 'decentralized_avg_train_accuracy': 0.95625, 'decentralized_avg_train_loss': 0.11405396638438106, 'decentralized_avg_eval_accuracy': 0.54}
# 141
# {'centralized_accuracy': 0.5, 'centralized_eval_loss': 1.8636665441357672, 'decentralized_avg_eval_loss': 2.0656654059886934, 'decentralized_avg_train_accuracy': 0.95546875, 'decentralized_avg_train_loss': 0.12530106934718788, 'decentralized_avg_eval_accuracy': 0.457}
# 142
# {'centralized_accuracy': 0.5193, 'centralized_eval_loss': 1.793253223355205, 'decentralized_avg_eval_loss': 1.854828527569771, 'decentralized_avg_train_accuracy': 0.95390625, 'decentralized_avg_train_loss': 0.12693165424279867, 'decentralized_avg_eval_accuracy': 0.493}
# 143
# {'centralized_accuracy': 0.5435, 'centralized_eval_loss': 1.6729013997906694, 'decentralized_avg_eval_loss': 1.6288607120513916, 'decentralized_avg_train_accuracy': 0.95703125, 'decentralized_avg_train_loss': 0.11332195657305419, 'decentralized_avg_eval_accuracy': 0.531}
# 144
# {'centralized_accuracy': 0.4929, 'centralized_eval_loss': 1.8793667006416443, 'decentralized_avg_eval_loss': 1.9232582747936249, 'decentralized_avg_train_accuracy': 0.97109375, 'decentralized_avg_train_loss': 0.08271651859395206, 'decentralized_avg_eval_accuracy': 0.5}
# 145
# {'centralized_accuracy': 0.5145, 'centralized_eval_loss': 1.7991364855354968, 'decentralized_avg_eval_loss': 1.8574503034353256, 'decentralized_avg_train_accuracy': 0.94296875, 'decentralized_avg_train_loss': 0.15735938162542878, 'decentralized_avg_eval_accuracy': 0.493}
# 146
# {'centralized_accuracy': 0.5373, 'centralized_eval_loss': 1.6858460360441725, 'decentralized_avg_eval_loss': 1.835570353269577, 'decentralized_avg_train_accuracy': 0.948046875, 'decentralized_avg_train_loss': 0.13735022200271488, 'decentralized_avg_eval_accuracy': 0.508}
# 147
# {'centralized_accuracy': 0.5406, 'centralized_eval_loss': 1.6629671033578939, 'decentralized_avg_eval_loss': 1.7826866209506989, 'decentralized_avg_train_accuracy': 0.963671875, 'decentralized_avg_train_loss': 0.1243297221371904, 'decentralized_avg_eval_accuracy': 0.485}
# 148
# {'centralized_accuracy': 0.5374, 'centralized_eval_loss': 1.663283943177793, 'decentralized_avg_eval_loss': 1.7008486956357955, 'decentralized_avg_train_accuracy': 0.965234375, 'decentralized_avg_train_loss': 0.09108968033688143, 'decentralized_avg_eval_accuracy': 0.525}
# 149
# {'centralized_accuracy': 0.5569, 'centralized_eval_loss': 1.6065911584007093, 'decentralized_avg_eval_loss': 1.7153972446918488, 'decentralized_avg_train_accuracy': 0.95859375, 'decentralized_avg_train_loss': 0.11758457368705422, 'decentralized_avg_eval_accuracy': 0.513}
# 150
# {'centralized_accuracy': 0.5531, 'centralized_eval_loss': 1.6042903707431146, 'decentralized_avg_eval_loss': 1.4814564555883407, 'decentralized_avg_train_accuracy': 0.98046875, 'decentralized_avg_train_loss': 0.0573065044474788, 'decentralized_avg_eval_accuracy': 0.585}
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>centralized_accuracy</td><td>▁▂▁▂▂▃▃▄▄▄▅▅▅▅▄▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████▇███</td></tr><tr><td>centralized_eval_loss</td><td>█▆▇▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>decentralized_avg_eval_accuracy</td><td>▁▂▂▂▁▃▂▄▅▃▄▆▆▆▆▆▆▆█▆▇▆▅▇▆▇▆▇▆▇▆▇▇▇█▇█▇▆▇</td></tr><tr><td>decentralized_avg_eval_loss</td><td>█▇▇▆▆▅▄▅▄▃▃▃▃▄▄▃▄▃▁▃▂▂▂▂▂▃▃▃▃▂▂▂▃▃▂▂▃▃▂▁</td></tr><tr><td>decentralized_avg_train_accuracy</td><td> ▂▁▂▁▂▂▃▃▄▅▅▅▅▆▆▆▅▆▆▆▇▆▇▇█▇▇▇▇▆█▇▇█▇▇▇▇█</td></tr><tr><td>decentralized_avg_train_loss</td><td>▆█▇▆▅▄▄▅▄▃▃▃▃▂▂▂▂▃▃▂▂▃▂▂▂▂▂▂▂▃▂▂▂▂▁▁▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>centralized_accuracy</td><td>0.5531</td></tr><tr><td>centralized_eval_loss</td><td>1.60429</td></tr><tr><td>decentralized_avg_eval_accuracy</td><td>0.585</td></tr><tr><td>decentralized_avg_eval_loss</td><td>1.48146</td></tr><tr><td>decentralized_avg_train_accuracy</td><td>0.98047</td></tr><tr><td>decentralized_avg_train_loss</td><td>0.05731</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">FL_Dino_Baseline_non_iid_5_4</strong> at: <a href='https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64/runs/FL_Dino_Baseline_non_iid_5_4' target="_blank">https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64/runs/FL_Dino_Baseline_non_iid_5_4</a><br> View project at: <a href='https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64' target="_blank">https://wandb.ai/stefano-gamba-social-politecnico-di-torino/FL_Dino_CIFAR100_base_new_batchsize64</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250602_201532-FL_Dino_Baseline_non_iid_5_4\logs</code>
