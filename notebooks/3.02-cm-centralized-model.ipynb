# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn as nn
from torch.nn import CrossEntropyLoss
import torch.optim as optim
from torch.optim import SGD
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts
from torchvision import datasets
from torch.utils.data import DataLoader

from torchvision import models
from torchvision.transforms import Compose, Resize, CenterCrop, RandomCrop, RandomHorizontalFlip, RandomVerticalFlip, Normalize, ToTensor

from fl_g13.config import RAW_DATA_DIR
from fl_g13.modeling import train, eval, save, load, backup
from fl_g13.dataset import train_test_split

from models import BaseDino
# Out:
# 2025-04-18 19:33:53.468 | INFO     | fl_g13.config:<module>:11 - PROJ_ROOT path is: /home/massimiliano/Projects/fl-g13

# %%
# Define preprocessing pipeline
train_transform = Compose([
    Resize(256), # CIFRA100 is originally 32x32
    RandomCrop(224), # But Dino works on 224x224
    RandomHorizontalFlip(),
    ToTensor(),
    Normalize(mean=[0.5071, 0.4866, 0.4409], std=[0.2673, 0.2564, 0.2762]),
])

eval_transform = Compose([
    Resize(256), # CIFRA100 is originally 32x32
    CenterCrop(224), # But Dino works on 224x224
    ToTensor(),
    Normalize(mean=[0.5071, 0.4866, 0.4409], std=[0.2673, 0.2564, 0.2762]),
])

cifar100_train = datasets.CIFAR100(root=RAW_DATA_DIR, train=True, download=True, transform=train_transform)
cifar100_test = datasets.CIFAR100(root=RAW_DATA_DIR, train=False, download=True, transform=eval_transform)

train_dataset, val_dataset = train_test_split(cifar100_train, 0.8, random_state=None)
test_dataset = cifar100_test

print(f"Train dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Train dataset size: 40000
# Validation dataset size: 10000
# Test dataset size: 10000

# %%
# Settings
CHECKPOINT_DIR = "/home/massimiliano/Projects/fl-g13/checkpoints"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

start_epoch=1
num_epochs=50
save_every=1
backup_every=10

# Hyper-parameters
BATCH_SIZE = 128
LR = 1e-2

# Dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Model
model = BaseDino()
model.to(device)
print(f"Model: {model}")

# Optimizer, scheduler, and loss function
optimizer = SGD(model.parameters(), lr=LR)
scheduler = CosineAnnealingWarmRestarts(
    optimizer, 
    T_0=8,           # First restart after 8 epochs
    T_mult=2,        # Double the interval between restarts each time
    eta_min=1e-5     # Minimum learning rate after annealing
)
criterion = CrossEntropyLoss()
# Out:
# Using device: cuda
# Using cache found in /home/massimiliano/.cache/torch/hub/facebookresearch_dino_main
# Model: BaseDino(
#   (net): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.1, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.1, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (head): Sequential(
#       (0): Linear(in_features=384, out_features=1024, bias=True)
#       (1): GELU(approximate='none')
#       (2): Dropout(p=0.1, inplace=False)
#       (3): Linear(in_features=1024, out_features=1024, bias=True)
#       (4): GELU(approximate='none')
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=1024, out_features=1024, bias=True)
#       (7): GELU(approximate='none')
#       (8): Dropout(p=0.1, inplace=False)
#       (9): Linear(in_features=1024, out_features=1024, bias=True)
#       (10): GELU(approximate='none')
#       (11): Dropout(p=0.1, inplace=False)
#       (12): Linear(in_features=1024, out_features=1024, bias=True)
#       (13): GELU(approximate='none')
#       (14): Dropout(p=0.1, inplace=False)
#       (15): Linear(in_features=1024, out_features=100, bias=True)
#     )
#   )
# )

# %%
print(f"Model head: {model.net.head}")
# Out:
# Model head: Sequential(
#   (0): Linear(in_features=384, out_features=1024, bias=True)
#   (1): GELU(approximate='none')
#   (2): Dropout(p=0.1, inplace=False)
#   (3): Linear(in_features=1024, out_features=1024, bias=True)
#   (4): GELU(approximate='none')
#   (5): Dropout(p=0.1, inplace=False)
#   (6): Linear(in_features=1024, out_features=1024, bias=True)
#   (7): GELU(approximate='none')
#   (8): Dropout(p=0.1, inplace=False)
#   (9): Linear(in_features=1024, out_features=1024, bias=True)
#   (10): GELU(approximate='none')
#   (11): Dropout(p=0.1, inplace=False)
#   (12): Linear(in_features=1024, out_features=1024, bias=True)
#   (13): GELU(approximate='none')
#   (14): Dropout(p=0.1, inplace=False)
#   (15): Linear(in_features=1024, out_features=100, bias=True)
# )

# %%
# Preallocated lists: if the training interrupts, it will still save their values
all_training_losses=[]       # Pre-allocated list for training losses
all_validation_losses=[]     # Pre-allocated list for validation losses
all_training_accuracies=[]   # Pre-allocated list for training accuracies
all_validation_accuracies=[] # Pre-allocated list for validation accuracies

name = "arceus"

try:
    _, _, _, _ = train(
        checkpoint_dir=CHECKPOINT_DIR,
        name=name,
        start_epoch=start_epoch,
        num_epochs=num_epochs,
        save_every=save_every,
        backup_every=backup_every
        train_dataloader=train_dataloader,
        val_dataloader=test_dataloader,
        model=model,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        verbose=False,
        all_training_losses=all_training_losses,
        all_validation_losses=all_validation_losses,
        all_training_accuracies=all_training_accuracies,
        all_validation_accuracies=all_validation_accuracies,
    )

except KeyboardInterrupt:
    print("Training interrupted manually. Backing up latest checkpoint...")

except Exception as e:
    print(f"Training stopped due to error: {e}")

finally:
    # This always runs no matter what (hopefully)
    backup(f"{CHECKPOINT_DIR}/{name}") # Backup the final checkpoint
# Out:
# Prefix/name for the model was provided: arceus
#
# 🚀 Epoch 1/50 (2.00%) Completed
# 	📊 Training Loss: 5.1833
# 	✅ Training Accuracy: 1.19%
# 	⏳ Elapsed Time: 132.65s | ETA: 6499.83s
# 	🕒 Completed At: 19:36
# 🔍 Validation Results:
# 	📉 Validation Loss: 4.7110
# 	🎯 Validation Accuracy: 2.23%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_1.pth
#
# 🚀 Epoch 2/50 (4.00%) Completed
# 	📊 Training Loss: 4.4243
# 	✅ Training Accuracy: 4.56%
# 	⏳ Elapsed Time: 132.07s | ETA: 6339.43s
# 	🕒 Completed At: 19:38
# 🔍 Validation Results:
# 	📉 Validation Loss: 4.2711
# 	🎯 Validation Accuracy: 13.56%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_2.pth
#
# 🚀 Epoch 3/50 (6.00%) Completed
# 	📊 Training Loss: 3.5806
# 	✅ Training Accuracy: 16.14%
# 	⏳ Elapsed Time: 132.42s | ETA: 6223.96s
# 	🕒 Completed At: 19:41
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.5573
# 	🎯 Validation Accuracy: 22.69%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_3.pth
#
# 🚀 Epoch 4/50 (8.00%) Completed
# 	📊 Training Loss: 3.1296
# 	✅ Training Accuracy: 23.88%
# 	⏳ Elapsed Time: 128.45s | ETA: 5908.67s
# 	🕒 Completed At: 19:43
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.4791
# 	🎯 Validation Accuracy: 25.70%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_4.pth
#
# 🚀 Epoch 5/50 (10.00%) Completed
# 	📊 Training Loss: 2.8894
# 	✅ Training Accuracy: 28.36%
# 	⏳ Elapsed Time: 128.90s | ETA: 5800.56s
# 	🕒 Completed At: 19:46
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.4732
# 	🎯 Validation Accuracy: 28.44%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_5.pth
#
# 🚀 Epoch 6/50 (12.00%) Completed
# 	📊 Training Loss: 2.7242
# 	✅ Training Accuracy: 31.31%
# 	⏳ Elapsed Time: 135.16s | ETA: 5946.96s
# 	🕒 Completed At: 19:48
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.3471
# 	🎯 Validation Accuracy: 30.63%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_6.pth
#
# 🚀 Epoch 7/50 (14.00%) Completed
# 	📊 Training Loss: 2.6241
# 	✅ Training Accuracy: 33.13%
# 	⏳ Elapsed Time: 135.37s | ETA: 5820.73s
# 	🕒 Completed At: 19:51
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.2954
# 	🎯 Validation Accuracy: 31.26%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_7.pth
#
# 🚀 Epoch 8/50 (16.00%) Completed
# 	📊 Training Loss: 2.5807
# 	✅ Training Accuracy: 34.12%
# 	⏳ Elapsed Time: 133.53s | ETA: 5608.24s
# 	🕒 Completed At: 19:54
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.3613
# 	🎯 Validation Accuracy: 31.49%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_8.pth
#
# 🚀 Epoch 9/50 (18.00%) Completed
# 	📊 Training Loss: 2.8535
# 	✅ Training Accuracy: 28.96%
# 	⏳ Elapsed Time: 118.15s | ETA: 4843.99s
# 	🕒 Completed At: 19:56
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.1712
# 	🎯 Validation Accuracy: 33.06%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_9.pth
#
# 🚀 Epoch 10/50 (20.00%) Completed
# 	📊 Training Loss: 2.6807
# 	✅ Training Accuracy: 32.16%
# 	⏳ Elapsed Time: 124.93s | ETA: 4997.34s
# 	🕒 Completed At: 19:59
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.0576
# 	🎯 Validation Accuracy: 34.47%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_10.pth
#
# 🚀 Epoch 11/50 (22.00%) Completed
# 	📊 Training Loss: 2.5544
# 	✅ Training Accuracy: 34.53%
# 	⏳ Elapsed Time: 121.34s | ETA: 4732.27s
# 	🕒 Completed At: 20:01
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.3942
# 	🎯 Validation Accuracy: 33.09%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_11.pth
#
# 🚀 Epoch 12/50 (24.00%) Completed
# 	📊 Training Loss: 2.4754
# 	✅ Training Accuracy: 36.51%
# 	⏳ Elapsed Time: 122.34s | ETA: 4648.91s
# 	🕒 Completed At: 20:03
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7515
# 	🎯 Validation Accuracy: 37.66%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_12.pth
#
# 🚀 Epoch 13/50 (26.00%) Completed
# 	📊 Training Loss: 2.3915
# 	✅ Training Accuracy: 38.04%
# 	⏳ Elapsed Time: 112.02s | ETA: 4144.76s
# 	🕒 Completed At: 20:05
# 🔍 Validation Results:
# 	📉 Validation Loss: 3.1073
# 	🎯 Validation Accuracy: 36.51%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_13.pth
#
# 🚀 Epoch 14/50 (28.00%) Completed
# 	📊 Training Loss: 2.3242
# 	✅ Training Accuracy: 39.43%
# 	⏳ Elapsed Time: 113.94s | ETA: 4101.75s
# 	🕒 Completed At: 20:08
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7275
# 	🎯 Validation Accuracy: 39.56%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_14.pth
#
# 🚀 Epoch 15/50 (30.00%) Completed
# 	📊 Training Loss: 2.2569
# 	✅ Training Accuracy: 40.97%
# 	⏳ Elapsed Time: 112.82s | ETA: 3948.69s
# 	🕒 Completed At: 20:10
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7026
# 	🎯 Validation Accuracy: 40.53%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_15.pth
#
# 🚀 Epoch 16/50 (32.00%) Completed
# 	📊 Training Loss: 2.2000
# 	✅ Training Accuracy: 41.89%
# 	⏳ Elapsed Time: 115.04s | ETA: 3911.34s
# 	🕒 Completed At: 20:12
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7919
# 	🎯 Validation Accuracy: 40.19%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_16.pth
#
# 🚀 Epoch 17/50 (34.00%) Completed
# 	📊 Training Loss: 2.1561
# 	✅ Training Accuracy: 42.98%
# 	⏳ Elapsed Time: 113.46s | ETA: 3744.10s
# 	🕒 Completed At: 20:14
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7644
# 	🎯 Validation Accuracy: 41.11%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_17.pth
#
# 🚀 Epoch 18/50 (36.00%) Completed
# 	📊 Training Loss: 2.1009
# 	✅ Training Accuracy: 43.98%
# 	⏳ Elapsed Time: 111.97s | ETA: 3582.98s
# 	🕒 Completed At: 20:17
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6952
# 	🎯 Validation Accuracy: 42.07%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_18.pth
#
# 🚀 Epoch 19/50 (38.00%) Completed
# 	📊 Training Loss: 2.0569
# 	✅ Training Accuracy: 45.19%
# 	⏳ Elapsed Time: 110.89s | ETA: 3437.70s
# 	🕒 Completed At: 20:19
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7766
# 	🎯 Validation Accuracy: 42.09%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_19.pth
#
# 🚀 Epoch 20/50 (40.00%) Completed
# 	📊 Training Loss: 2.0276
# 	✅ Training Accuracy: 45.86%
# 	⏳ Elapsed Time: 111.83s | ETA: 3354.95s
# 	🕒 Completed At: 20:21
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7569
# 	🎯 Validation Accuracy: 42.27%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_20.pth
#
# 🚀 Epoch 21/50 (42.00%) Completed
# 	📊 Training Loss: 1.9882
# 	✅ Training Accuracy: 46.60%
# 	⏳ Elapsed Time: 110.78s | ETA: 3212.55s
# 	🕒 Completed At: 20:23
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7214
# 	🎯 Validation Accuracy: 42.68%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_21.pth
#
# 🚀 Epoch 22/50 (44.00%) Completed
# 	📊 Training Loss: 1.9700
# 	✅ Training Accuracy: 46.98%
# 	⏳ Elapsed Time: 112.45s | ETA: 3148.65s
# 	🕒 Completed At: 20:25
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7695
# 	🎯 Validation Accuracy: 42.62%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_22.pth
#
# 🚀 Epoch 23/50 (46.00%) Completed
# 	📊 Training Loss: 1.9553
# 	✅ Training Accuracy: 47.23%
# 	⏳ Elapsed Time: 113.51s | ETA: 3064.84s
# 	🕒 Completed At: 20:27
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7731
# 	🎯 Validation Accuracy: 42.49%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_23.pth
#
# 🚀 Epoch 24/50 (48.00%) Completed
# 	📊 Training Loss: 1.9385
# 	✅ Training Accuracy: 47.85%
# 	⏳ Elapsed Time: 121.08s | ETA: 3148.11s
# 	🕒 Completed At: 20:30
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7689
# 	🎯 Validation Accuracy: 42.64%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_24.pth
#
# 🚀 Epoch 25/50 (50.00%) Completed
# 	📊 Training Loss: 2.2386
# 	✅ Training Accuracy: 41.25%
# 	⏳ Elapsed Time: 126.63s | ETA: 3165.74s
# 	🕒 Completed At: 20:32
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6441
# 	🎯 Validation Accuracy: 42.59%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_25.pth
#
# 🚀 Epoch 26/50 (52.00%) Completed
# 	📊 Training Loss: 2.1898
# 	✅ Training Accuracy: 42.14%
# 	⏳ Elapsed Time: 123.43s | ETA: 2962.28s
# 	🕒 Completed At: 20:35
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6507
# 	🎯 Validation Accuracy: 41.96%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_26.pth
#
# 🚀 Epoch 27/50 (54.00%) Completed
# 	📊 Training Loss: 2.1463
# 	✅ Training Accuracy: 43.25%
# 	⏳ Elapsed Time: 126.84s | ETA: 2917.32s
# 	🕒 Completed At: 20:37
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7207
# 	🎯 Validation Accuracy: 41.96%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_27.pth
#
# 🚀 Epoch 28/50 (56.00%) Completed
# 	📊 Training Loss: 2.1132
# 	✅ Training Accuracy: 43.73%
# 	⏳ Elapsed Time: 128.11s | ETA: 2818.36s
# 	🕒 Completed At: 20:40
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8432
# 	🎯 Validation Accuracy: 41.59%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_28.pth
#
# 🚀 Epoch 29/50 (58.00%) Completed
# 	📊 Training Loss: 2.0750
# 	✅ Training Accuracy: 44.76%
# 	⏳ Elapsed Time: 127.11s | ETA: 2669.23s
# 	🕒 Completed At: 20:42
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7245
# 	🎯 Validation Accuracy: 41.46%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_29.pth
#
# 🚀 Epoch 30/50 (60.00%) Completed
# 	📊 Training Loss: 2.0410
# 	✅ Training Accuracy: 45.30%
# 	⏳ Elapsed Time: 132.56s | ETA: 2651.14s
# 	🕒 Completed At: 20:45
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6458
# 	🎯 Validation Accuracy: 43.18%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_30.pth
#
# 🚀 Epoch 31/50 (62.00%) Completed
# 	📊 Training Loss: 2.0162
# 	✅ Training Accuracy: 46.17%
# 	⏳ Elapsed Time: 136.67s | ETA: 2596.79s
# 	🕒 Completed At: 20:47
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7966
# 	🎯 Validation Accuracy: 41.20%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_31.pth
#
# 🚀 Epoch 32/50 (64.00%) Completed
# 	📊 Training Loss: 1.9775
# 	✅ Training Accuracy: 46.89%
# 	⏳ Elapsed Time: 135.55s | ETA: 2439.93s
# 	🕒 Completed At: 20:50
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6918
# 	🎯 Validation Accuracy: 42.23%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_32.pth
#
# 🚀 Epoch 33/50 (66.00%) Completed
# 	📊 Training Loss: 1.9477
# 	✅ Training Accuracy: 47.67%
# 	⏳ Elapsed Time: 136.11s | ETA: 2313.82s
# 	🕒 Completed At: 20:53
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8264
# 	🎯 Validation Accuracy: 41.78%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_33.pth
#
# 🚀 Epoch 34/50 (68.00%) Completed
# 	📊 Training Loss: 1.9224
# 	✅ Training Accuracy: 48.22%
# 	⏳ Elapsed Time: 135.44s | ETA: 2166.97s
# 	🕒 Completed At: 20:55
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.5929
# 	🎯 Validation Accuracy: 44.58%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_34.pth
#
# 🚀 Epoch 35/50 (70.00%) Completed
# 	📊 Training Loss: 1.8848
# 	✅ Training Accuracy: 48.69%
# 	⏳ Elapsed Time: 135.84s | ETA: 2037.64s
# 	🕒 Completed At: 20:58
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6463
# 	🎯 Validation Accuracy: 43.68%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_35.pth
#
# 🚀 Epoch 36/50 (72.00%) Completed
# 	📊 Training Loss: 1.8467
# 	✅ Training Accuracy: 49.88%
# 	⏳ Elapsed Time: 132.59s | ETA: 1856.26s
# 	🕒 Completed At: 21:01
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7242
# 	🎯 Validation Accuracy: 43.37%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_36.pth
#
# 🚀 Epoch 37/50 (74.00%) Completed
# 	📊 Training Loss: 1.8211
# 	✅ Training Accuracy: 50.46%
# 	⏳ Elapsed Time: 131.45s | ETA: 1708.79s
# 	🕒 Completed At: 21:03
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7330
# 	🎯 Validation Accuracy: 43.65%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_37.pth
#
# 🚀 Epoch 38/50 (76.00%) Completed
# 	📊 Training Loss: 1.7968
# 	✅ Training Accuracy: 51.09%
# 	⏳ Elapsed Time: 117.44s | ETA: 1409.24s
# 	🕒 Completed At: 21:05
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8781
# 	🎯 Validation Accuracy: 42.22%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_38.pth
#
# 🚀 Epoch 39/50 (78.00%) Completed
# 	📊 Training Loss: 1.7693
# 	✅ Training Accuracy: 51.62%
# 	⏳ Elapsed Time: 123.43s | ETA: 1357.68s
# 	🕒 Completed At: 21:08
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7761
# 	🎯 Validation Accuracy: 43.59%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_39.pth
#
# 🚀 Epoch 40/50 (80.00%) Completed
# 	📊 Training Loss: 1.7346
# 	✅ Training Accuracy: 52.53%
# 	⏳ Elapsed Time: 127.44s | ETA: 1274.41s
# 	🕒 Completed At: 21:10
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.6081
# 	🎯 Validation Accuracy: 45.80%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_40.pth
#
# 🚀 Epoch 41/50 (82.00%) Completed
# 	📊 Training Loss: 1.7040
# 	✅ Training Accuracy: 53.01%
# 	⏳ Elapsed Time: 127.22s | ETA: 1145.00s
# 	🕒 Completed At: 21:13
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8604
# 	🎯 Validation Accuracy: 44.12%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_41.pth
#
# 🚀 Epoch 42/50 (84.00%) Completed
# 	📊 Training Loss: 1.6809
# 	✅ Training Accuracy: 53.69%
# 	⏳ Elapsed Time: 128.93s | ETA: 1031.44s
# 	🕒 Completed At: 21:15
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7699
# 	🎯 Validation Accuracy: 44.97%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_42.pth
#
# 🚀 Epoch 43/50 (86.00%) Completed
# 	📊 Training Loss: 1.6598
# 	✅ Training Accuracy: 53.89%
# 	⏳ Elapsed Time: 124.53s | ETA: 871.71s
# 	🕒 Completed At: 21:18
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8275
# 	🎯 Validation Accuracy: 45.49%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_43.pth
#
# 🚀 Epoch 44/50 (88.00%) Completed
# 	📊 Training Loss: 1.6253
# 	✅ Training Accuracy: 54.87%
# 	⏳ Elapsed Time: 121.90s | ETA: 731.41s
# 	🕒 Completed At: 21:20
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7989
# 	🎯 Validation Accuracy: 45.41%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_44.pth
#
# 🚀 Epoch 45/50 (90.00%) Completed
# 	📊 Training Loss: 1.6053
# 	✅ Training Accuracy: 55.38%
# 	⏳ Elapsed Time: 129.89s | ETA: 649.44s
# 	🕒 Completed At: 21:23
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8712
# 	🎯 Validation Accuracy: 44.85%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_45.pth
#
# 🚀 Epoch 46/50 (92.00%) Completed
# 	📊 Training Loss: 1.5725
# 	✅ Training Accuracy: 55.80%
# 	⏳ Elapsed Time: 127.24s | ETA: 508.98s
# 	🕒 Completed At: 21:25
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.7839
# 	🎯 Validation Accuracy: 46.48%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_46.pth
#
# 🚀 Epoch 47/50 (94.00%) Completed
# 	📊 Training Loss: 1.5535
# 	✅ Training Accuracy: 56.48%
# 	⏳ Elapsed Time: 128.80s | ETA: 386.41s
# 	🕒 Completed At: 21:28
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8222
# 	🎯 Validation Accuracy: 45.13%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_47.pth
#
# 🚀 Epoch 48/50 (96.00%) Completed
# 	📊 Training Loss: 1.5312
# 	✅ Training Accuracy: 57.12%
# 	⏳ Elapsed Time: 125.75s | ETA: 251.50s
# 	🕒 Completed At: 21:30
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8758
# 	🎯 Validation Accuracy: 44.98%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_48.pth
#
# 🚀 Epoch 49/50 (98.00%) Completed
# 	📊 Training Loss: 1.5183
# 	✅ Training Accuracy: 57.74%
# 	⏳ Elapsed Time: 125.29s | ETA: 125.29s
# 	🕒 Completed At: 21:33
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.8013
# 	🎯 Validation Accuracy: 46.39%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_49.pth
#
# 🚀 Epoch 50/50 (100.00%) Completed
# 	📊 Training Loss: 1.5058
# 	✅ Training Accuracy: 57.77%
# 	⏳ Elapsed Time: 126.29s | ETA: 0.00s
# 	🕒 Completed At: 21:35
# 🔍 Validation Results:
# 	📉 Validation Loss: 2.9130
# 	🎯 Validation Accuracy: 45.19%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/arceus_BaseDino_epoch_50.pth

# %%
import matplotlib.pyplot as plt

# Plot losses
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(all_training_losses, label='Training Loss')
plt.plot(all_validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend()

# Plot accuracies
plt.subplot(1, 2, 2)
plt.plot(all_training_accuracies, label='Training Accuracy')
plt.plot(all_validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model on the validation dataset
test_loss, test_accuracy, _ = eval(dataloader=test_dataloader, model=model, criterion=criterion)

print(
    f"🔍 Test Results:\n"
    f"\t📉 Test Loss: {test_loss:.4f}\n"
    f"\t🎯 Test Accuracy: {100 * test_accuracy:.2f}%"
)
# Out:
# 🔍 Test Results:
# 	📉 Test Loss: 2.9130
# 	🎯 Test Accuracy: 45.19%
