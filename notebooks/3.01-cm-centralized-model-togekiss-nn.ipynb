# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn as nn
from torch.nn import CrossEntropyLoss
import torch.optim as optim
from torch.optim import SGD
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts
from torchvision import datasets
from torch.utils.data import DataLoader

from torchvision import models
from torchvision.transforms import Compose, Resize, CenterCrop, RandomCrop, RandomHorizontalFlip, RandomVerticalFlip, Normalize, ToTensor

from fl_g13.config import RAW_DATA_DIR
from fl_g13.modeling import train, eval, save, load, backup, load_loss_and_accuracies, save_loss_and_accuracy
from fl_g13.dataset import train_test_split

from fl_g13.architectures import BaseDino
# Out:
# 2025-04-24 18:08:10.092 | INFO     | fl_g13.config:<module>:11 - PROJ_ROOT path is: /home/massimiliano/Projects/fl-g13

# %%
# Define preprocessing pipeline
train_transform = Compose([
    Resize(256), # CIFRA100 is originally 32x32
    RandomCrop(224), # But Dino works on 224x224
    RandomHorizontalFlip(),
    ToTensor(),
    #Normalize(mean=[0.5071, 0.4866, 0.4409], std=[0.2673, 0.2564, 0.2762]),
    Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
])

eval_transform = Compose([
    Resize(256), # CIFRA100 is originally 32x32
    CenterCrop(224), # But Dino works on 224x224
    ToTensor(),
    #Normalize(mean=[0.5071, 0.4866, 0.4409], std=[0.2673, 0.2564, 0.2762]),
    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

cifar100_train = datasets.CIFAR100(root=RAW_DATA_DIR, train=True, download=True, transform=train_transform)
cifar100_test = datasets.CIFAR100(root=RAW_DATA_DIR, train=False, download=True, transform=eval_transform)

train_dataset, val_dataset = train_test_split(cifar100_train, 0.8, random_state=None)
test_dataset = cifar100_test

print(f"Train dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
# Out:
# Train dataset size: 40000
# Validation dataset size: 10000
# Test dataset size: 10000

# %%
# Move to CUDA
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Settings
CHECKPOINT_DIR = "/home/massimiliano/Projects/fl-g13/checkpoints"
name = "togekiss-nn"
start_epoch=1
num_epochs=45
save_every=5
backup_every=10

# Hyper-parameters
BATCH_SIZE = 128
LR = 1e-3

# Dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Model
model = BaseDino(head_layers=5, head_hidden_size=512, dropout_rate=0.0, unfreeze_blocks=1)
model.to(device)
# Optimizer, scheduler, and loss function
optimizer = SGD(model.parameters(), lr=LR)
scheduler = CosineAnnealingWarmRestarts(
    optimizer, 
    T_0=15,           # First restart after 12 epochs
    T_mult=2,        # Double the interval between restarts each time
    eta_min=1e-6     # Minimum learning rate after annealing
)
criterion = CrossEntropyLoss()

all_training_losses=[]       # Pre-allocated list for training losses
all_validation_losses=[]       # Pre-allocated list for validation losses
all_training_accuracies=[]    # Pre-allocated list for training accuracies
all_validation_accuracies=[]    # Pre-allocated list for validation accuracies

# # Model loading (uncomment to properly overwrite)
# model, start_epoch = load(
#     f"{CHECKPOINT_DIR}/BaseDino/togekiss-nn_BaseDino_epoch_x.pth",
#     model_class=BaseDino,
#     device=device,
#     optimizer=optimizer,
#     scheduler=scheduler,
#     verbose=True
# )
# model.to(device)
# loaded_metrics = load_loss_and_accuracies(path=f"{CHECKPOINT_DIR}/BaseDino/togekiss-nn_BaseDino_epoch_x.loss_acc.json")

# Preallocated lists: if the training interrupts, it will still save their values
# all_training_losses=loaded_metrics["train_loss"]       # Pre-allocated list for training losses
# all_validation_losses=loaded_metrics["val_loss"]       # Pre-allocated list for validation losses
# all_training_accuracies=loaded_metrics["train_acc"]    # Pre-allocated list for training accuracies
# all_validation_accuracies=loaded_metrics["val_acc"]    # Pre-allocated list for validation accuracies

print(f"\nModel: {model}")
# Out:
# Using device: cuda
# Using cache found in /home/massimiliano/.cache/torch/hub/facebookresearch_dino_main
# Model: BaseDino(
#   (net): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (blocks): ModuleList(
#       (0-11): 12 x Block(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (drop_path): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#     (head): Sequential(
#       (0): Linear(in_features=384, out_features=512, bias=True)
#       (1): GELU(approximate='none')
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): GELU(approximate='none')
#       (5): Dropout(p=0.0, inplace=False)
#       (6): Linear(in_features=512, out_features=512, bias=True)
#       (7): GELU(approximate='none')
#       (8): Dropout(p=0.0, inplace=False)
#       (9): Linear(in_features=512, out_features=512, bias=True)
#       (10): GELU(approximate='none')
#       (11): Dropout(p=0.0, inplace=False)
#       (12): Linear(in_features=512, out_features=512, bias=True)
#       (13): GELU(approximate='none')
#       (14): Dropout(p=0.0, inplace=False)
#       (15): Linear(in_features=512, out_features=100, bias=True)
#     )
#   )
# )

# %%
try:
    _, _, _, _ = train(
        checkpoint_dir=CHECKPOINT_DIR,
        name=name,
        start_epoch=start_epoch,
        num_epochs=num_epochs,
        save_every=save_every,
        backup_every=backup_every,
        train_dataloader=train_dataloader,
        val_dataloader=val_dataloader,
        model=model,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        verbose=False,
        all_training_losses=all_training_losses,
        all_validation_losses=all_validation_losses,
        all_training_accuracies=all_training_accuracies,
        all_validation_accuracies=all_validation_accuracies,
    )

except KeyboardInterrupt:
    print("Training interrupted manually. Backing up latest checkpoint...")

except Exception as e:
    print(f"Training stopped due to error: {e}")
# Out:
# Prefix/name for the model was provided: togekiss-nn
#
# 🚀 Epoch 1/45 (2.22%) Completed
# 	📊 Training Loss: 2.5520
# 	✅ Training Accuracy: 43.36%
# 	⏳ Elapsed Time: 83.44s | ETA: 3671.24s
# 	🕒 Completed At: 18:09
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.4984
# 	🎯 Validation Accuracy: 57.08%
#
# 🚀 Epoch 2/45 (4.44%) Completed
# 	📊 Training Loss: 1.1626
# 	✅ Training Accuracy: 66.47%
# 	⏳ Elapsed Time: 84.69s | ETA: 3641.65s
# 	🕒 Completed At: 18:11
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.1800
# 	🎯 Validation Accuracy: 66.69%
#
# 🚀 Epoch 3/45 (6.67%) Completed
# 	📊 Training Loss: 0.9878
# 	✅ Training Accuracy: 70.86%
# 	⏳ Elapsed Time: 83.97s | ETA: 3526.73s
# 	🕒 Completed At: 18:13
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.1110
# 	🎯 Validation Accuracy: 67.46%
#
# 🚀 Epoch 4/45 (8.89%) Completed
# 	📊 Training Loss: 0.8788
# 	✅ Training Accuracy: 73.86%
# 	⏳ Elapsed Time: 84.07s | ETA: 3446.73s
# 	🕒 Completed At: 18:14
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0772
# 	🎯 Validation Accuracy: 69.61%
#
# 🚀 Epoch 5/45 (11.11%) Completed
# 	📊 Training Loss: 0.8102
# 	✅ Training Accuracy: 75.70%
# 	⏳ Elapsed Time: 84.86s | ETA: 3394.29s
# 	🕒 Completed At: 18:16
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.1222
# 	🎯 Validation Accuracy: 68.03%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_5.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_5.loss_acc.json
#
# 🚀 Epoch 6/45 (13.33%) Completed
# 	📊 Training Loss: 0.7593
# 	✅ Training Accuracy: 77.14%
# 	⏳ Elapsed Time: 85.89s | ETA: 3349.72s
# 	🕒 Completed At: 18:18
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9719
# 	🎯 Validation Accuracy: 71.68%
#
# 🚀 Epoch 7/45 (15.56%) Completed
# 	📊 Training Loss: 0.7074
# 	✅ Training Accuracy: 78.46%
# 	⏳ Elapsed Time: 85.42s | ETA: 3245.94s
# 	🕒 Completed At: 18:19
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9690
# 	🎯 Validation Accuracy: 71.32%
#
# 🚀 Epoch 8/45 (17.78%) Completed
# 	📊 Training Loss: 0.6697
# 	✅ Training Accuracy: 79.44%
# 	⏳ Elapsed Time: 85.46s | ETA: 3161.86s
# 	🕒 Completed At: 18:21
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9115
# 	🎯 Validation Accuracy: 73.43%
#
# 🚀 Epoch 9/45 (20.00%) Completed
# 	📊 Training Loss: 0.6301
# 	✅ Training Accuracy: 80.63%
# 	⏳ Elapsed Time: 86.06s | ETA: 3098.01s
# 	🕒 Completed At: 18:23
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.8962
# 	🎯 Validation Accuracy: 74.31%
#
# 🚀 Epoch 10/45 (22.22%) Completed
# 	📊 Training Loss: 0.5984
# 	✅ Training Accuracy: 81.55%
# 	⏳ Elapsed Time: 85.84s | ETA: 3004.41s
# 	🕒 Completed At: 18:25
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9017
# 	🎯 Validation Accuracy: 74.96%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_10.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_10.loss_acc.json
#
# Running backup for epoch 10
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_182534_togekiss-nn_BaseDino_epoch_10.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_182534_togekiss-nn_BaseDino_epoch_10.loss_acc.json
#
# 🚀 Epoch 11/45 (24.44%) Completed
# 	📊 Training Loss: 0.5721
# 	✅ Training Accuracy: 82.58%
# 	⏳ Elapsed Time: 84.91s | ETA: 2886.84s
# 	🕒 Completed At: 18:26
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.8800
# 	🎯 Validation Accuracy: 75.23%
#
# 🚀 Epoch 12/45 (26.67%) Completed
# 	📊 Training Loss: 0.5510
# 	✅ Training Accuracy: 83.27%
# 	⏳ Elapsed Time: 85.46s | ETA: 2820.34s
# 	🕒 Completed At: 18:28
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.8815
# 	🎯 Validation Accuracy: 74.88%
#
# 🚀 Epoch 13/45 (28.89%) Completed
# 	📊 Training Loss: 0.5326
# 	✅ Training Accuracy: 83.88%
# 	⏳ Elapsed Time: 85.43s | ETA: 2733.85s
# 	🕒 Completed At: 18:30
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.8810
# 	🎯 Validation Accuracy: 75.22%
#
# 🚀 Epoch 14/45 (31.11%) Completed
# 	📊 Training Loss: 0.5162
# 	✅ Training Accuracy: 84.19%
# 	⏳ Elapsed Time: 85.22s | ETA: 2641.91s
# 	🕒 Completed At: 18:32
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.8719
# 	🎯 Validation Accuracy: 75.59%
#
# 🚀 Epoch 15/45 (33.33%) Completed
# 	📊 Training Loss: 0.5114
# 	✅ Training Accuracy: 84.31%
# 	⏳ Elapsed Time: 85.14s | ETA: 2554.08s
# 	🕒 Completed At: 18:33
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.8735
# 	🎯 Validation Accuracy: 75.52%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_15.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_15.loss_acc.json
#
# 🚀 Epoch 16/45 (35.56%) Completed
# 	📊 Training Loss: 0.7284
# 	✅ Training Accuracy: 77.54%
# 	⏳ Elapsed Time: 84.99s | ETA: 2464.67s
# 	🕒 Completed At: 18:35
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0355
# 	🎯 Validation Accuracy: 71.00%
#
# 🚀 Epoch 17/45 (37.78%) Completed
# 	📊 Training Loss: 0.6814
# 	✅ Training Accuracy: 78.99%
# 	⏳ Elapsed Time: 85.60s | ETA: 2396.90s
# 	🕒 Completed At: 18:37
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9823
# 	🎯 Validation Accuracy: 71.85%
#
# 🚀 Epoch 18/45 (40.00%) Completed
# 	📊 Training Loss: 0.6647
# 	✅ Training Accuracy: 79.34%
# 	⏳ Elapsed Time: 85.51s | ETA: 2308.78s
# 	🕒 Completed At: 18:39
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0907
# 	🎯 Validation Accuracy: 69.79%
#
# 🚀 Epoch 19/45 (42.22%) Completed
# 	📊 Training Loss: 0.6383
# 	✅ Training Accuracy: 80.27%
# 	⏳ Elapsed Time: 85.44s | ETA: 2221.38s
# 	🕒 Completed At: 18:40
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9773
# 	🎯 Validation Accuracy: 72.51%
#
# 🚀 Epoch 20/45 (44.44%) Completed
# 	📊 Training Loss: 0.6113
# 	✅ Training Accuracy: 81.02%
# 	⏳ Elapsed Time: 85.45s | ETA: 2136.33s
# 	🕒 Completed At: 18:42
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0529
# 	🎯 Validation Accuracy: 71.33%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_20.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_20.loss_acc.json
#
# Running backup for epoch 20
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_184300_togekiss-nn_BaseDino_epoch_20.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_184300_togekiss-nn_BaseDino_epoch_20.loss_acc.json
#
# 🚀 Epoch 21/45 (46.67%) Completed
# 	📊 Training Loss: 0.5901
# 	✅ Training Accuracy: 81.55%
# 	⏳ Elapsed Time: 85.35s | ETA: 2048.47s
# 	🕒 Completed At: 18:44
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9824
# 	🎯 Validation Accuracy: 72.98%
#
# 🚀 Epoch 22/45 (48.89%) Completed
# 	📊 Training Loss: 0.5729
# 	✅ Training Accuracy: 81.97%
# 	⏳ Elapsed Time: 86.09s | ETA: 1980.03s
# 	🕒 Completed At: 18:46
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0041
# 	🎯 Validation Accuracy: 71.97%
#
# 🚀 Epoch 23/45 (51.11%) Completed
# 	📊 Training Loss: 0.5488
# 	✅ Training Accuracy: 82.84%
# 	⏳ Elapsed Time: 86.28s | ETA: 1898.06s
# 	🕒 Completed At: 18:47
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0895
# 	🎯 Validation Accuracy: 70.15%
#
# 🚀 Epoch 24/45 (53.33%) Completed
# 	📊 Training Loss: 0.5352
# 	✅ Training Accuracy: 83.16%
# 	⏳ Elapsed Time: 86.03s | ETA: 1806.65s
# 	🕒 Completed At: 18:49
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9869
# 	🎯 Validation Accuracy: 73.35%
#
# 🚀 Epoch 25/45 (55.56%) Completed
# 	📊 Training Loss: 0.5102
# 	✅ Training Accuracy: 83.77%
# 	⏳ Elapsed Time: 85.87s | ETA: 1717.33s
# 	🕒 Completed At: 18:51
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0290
# 	🎯 Validation Accuracy: 72.58%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_25.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_25.loss_acc.json
#
# 🚀 Epoch 26/45 (57.78%) Completed
# 	📊 Training Loss: 0.4910
# 	✅ Training Accuracy: 84.32%
# 	⏳ Elapsed Time: 85.31s | ETA: 1620.94s
# 	🕒 Completed At: 18:53
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0180
# 	🎯 Validation Accuracy: 73.96%
#
# 🚀 Epoch 27/45 (60.00%) Completed
# 	📊 Training Loss: 0.4739
# 	✅ Training Accuracy: 84.80%
# 	⏳ Elapsed Time: 85.92s | ETA: 1546.62s
# 	🕒 Completed At: 18:54
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0074
# 	🎯 Validation Accuracy: 73.60%
#
# 🚀 Epoch 28/45 (62.22%) Completed
# 	📊 Training Loss: 0.4557
# 	✅ Training Accuracy: 85.50%
# 	⏳ Elapsed Time: 85.84s | ETA: 1459.23s
# 	🕒 Completed At: 18:56
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9962
# 	🎯 Validation Accuracy: 73.53%
#
# 🚀 Epoch 29/45 (64.44%) Completed
# 	📊 Training Loss: 0.4349
# 	✅ Training Accuracy: 86.19%
# 	⏳ Elapsed Time: 85.61s | ETA: 1369.83s
# 	🕒 Completed At: 18:58
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0030
# 	🎯 Validation Accuracy: 74.21%
#
# 🚀 Epoch 30/45 (66.67%) Completed
# 	📊 Training Loss: 0.4214
# 	✅ Training Accuracy: 86.56%
# 	⏳ Elapsed Time: 85.72s | ETA: 1285.85s
# 	🕒 Completed At: 19:00
# 🔍 Validation Results:
# 	📉 Validation Loss: 0.9841
# 	🎯 Validation Accuracy: 74.26%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_30.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_30.loss_acc.json
#
# Running backup for epoch 30
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_190032_togekiss-nn_BaseDino_epoch_30.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_190032_togekiss-nn_BaseDino_epoch_30.loss_acc.json
#
# 🚀 Epoch 31/45 (68.89%) Completed
# 	📊 Training Loss: 0.3979
# 	✅ Training Accuracy: 87.22%
# 	⏳ Elapsed Time: 84.95s | ETA: 1189.23s
# 	🕒 Completed At: 19:01
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0018
# 	🎯 Validation Accuracy: 74.30%
#
# 🚀 Epoch 32/45 (71.11%) Completed
# 	📊 Training Loss: 0.3794
# 	✅ Training Accuracy: 87.73%
# 	⏳ Elapsed Time: 85.78s | ETA: 1115.19s
# 	🕒 Completed At: 19:03
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0214
# 	🎯 Validation Accuracy: 74.06%
#
# 🚀 Epoch 33/45 (73.33%) Completed
# 	📊 Training Loss: 0.3649
# 	✅ Training Accuracy: 88.39%
# 	⏳ Elapsed Time: 84.32s | ETA: 1011.81s
# 	🕒 Completed At: 19:05
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0221
# 	🎯 Validation Accuracy: 74.82%
#
# 🚀 Epoch 34/45 (75.56%) Completed
# 	📊 Training Loss: 0.3442
# 	✅ Training Accuracy: 88.88%
# 	⏳ Elapsed Time: 84.70s | ETA: 931.71s
# 	🕒 Completed At: 19:07
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0318
# 	🎯 Validation Accuracy: 74.52%
#
# 🚀 Epoch 35/45 (77.78%) Completed
# 	📊 Training Loss: 0.3325
# 	✅ Training Accuracy: 89.15%
# 	⏳ Elapsed Time: 85.46s | ETA: 854.64s
# 	🕒 Completed At: 19:08
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0350
# 	🎯 Validation Accuracy: 74.95%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_35.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_35.loss_acc.json
#
# 🚀 Epoch 36/45 (80.00%) Completed
# 	📊 Training Loss: 0.3185
# 	✅ Training Accuracy: 89.81%
# 	⏳ Elapsed Time: 84.01s | ETA: 756.12s
# 	🕒 Completed At: 19:10
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0345
# 	🎯 Validation Accuracy: 74.68%
#
# 🚀 Epoch 37/45 (82.22%) Completed
# 	📊 Training Loss: 0.3067
# 	✅ Training Accuracy: 90.18%
# 	⏳ Elapsed Time: 85.04s | ETA: 680.30s
# 	🕒 Completed At: 19:12
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0164
# 	🎯 Validation Accuracy: 74.98%
#
# 🚀 Epoch 38/45 (84.44%) Completed
# 	📊 Training Loss: 0.2879
# 	✅ Training Accuracy: 90.90%
# 	⏳ Elapsed Time: 85.50s | ETA: 598.49s
# 	🕒 Completed At: 19:14
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0380
# 	🎯 Validation Accuracy: 74.91%
#
# 🚀 Epoch 39/45 (86.67%) Completed
# 	📊 Training Loss: 0.2831
# 	✅ Training Accuracy: 90.88%
# 	⏳ Elapsed Time: 87.22s | ETA: 523.32s
# 	🕒 Completed At: 19:15
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0318
# 	🎯 Validation Accuracy: 75.26%
#
# 🚀 Epoch 40/45 (88.89%) Completed
# 	📊 Training Loss: 0.2725
# 	✅ Training Accuracy: 91.30%
# 	⏳ Elapsed Time: 86.66s | ETA: 433.30s
# 	🕒 Completed At: 19:17
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0289
# 	🎯 Validation Accuracy: 75.21%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_40.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_40.loss_acc.json
#
# Running backup for epoch 40
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_191759_togekiss-nn_BaseDino_epoch_40.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/backup/BaseDino/backup_20250424_191759_togekiss-nn_BaseDino_epoch_40.loss_acc.json
#
# 🚀 Epoch 41/45 (91.11%) Completed
# 	📊 Training Loss: 0.2694
# 	✅ Training Accuracy: 91.57%
# 	⏳ Elapsed Time: 85.00s | ETA: 340.00s
# 	🕒 Completed At: 19:19
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0340
# 	🎯 Validation Accuracy: 75.31%
#
# 🚀 Epoch 42/45 (93.33%) Completed
# 	📊 Training Loss: 0.2606
# 	✅ Training Accuracy: 91.99%
# 	⏳ Elapsed Time: 85.30s | ETA: 255.90s
# 	🕒 Completed At: 19:21
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0425
# 	🎯 Validation Accuracy: 74.91%
#
# 🚀 Epoch 43/45 (95.56%) Completed
# 	📊 Training Loss: 0.2572
# 	✅ Training Accuracy: 91.87%
# 	⏳ Elapsed Time: 85.37s | ETA: 170.74s
# 	🕒 Completed At: 19:22
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0458
# 	🎯 Validation Accuracy: 75.09%
#
# 🚀 Epoch 44/45 (97.78%) Completed
# 	📊 Training Loss: 0.2564
# 	✅ Training Accuracy: 91.97%
# 	⏳ Elapsed Time: 85.56s | ETA: 85.56s
# 	🕒 Completed At: 19:24
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0234
# 	🎯 Validation Accuracy: 75.68%
#
# 🚀 Epoch 45/45 (100.00%) Completed
# 	📊 Training Loss: 0.2517
# 	✅ Training Accuracy: 91.96%
# 	⏳ Elapsed Time: 85.73s | ETA: 0.00s
# 	🕒 Completed At: 19:26
# 🔍 Validation Results:
# 	📉 Validation Loss: 1.0285
# 	🎯 Validation Accuracy: 75.48%
#
# 💾 Saved checkpoint at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_45.pth
# 💾 Saved losses and accuracies (training and validation) at: /home/massimiliano/Projects/fl-g13/checkpoints/BaseDino/togekiss-nn_BaseDino_epoch_45.loss_acc.json

# %%
import matplotlib.pyplot as plt

# Plot losses
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(all_training_losses, label='Training Loss')
plt.plot(all_validation_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend()

# Plot accuracies
plt.subplot(1, 2, 2)
plt.plot(all_training_accuracies, label='Training Accuracy')
plt.plot(all_validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model on the validation dataset
test_loss, test_accuracy, _ = eval(dataloader=test_dataloader, model=model, criterion=criterion)

print(
    f"🔍 Test Results:\n"
    f"\t📉 Test Loss: {test_loss:.4f}\n"
    f"\t🎯 Test Accuracy: {100 * test_accuracy:.2f}%"
)
# Out:
# 🔍 Test Results:
# 	📉 Test Loss: 1.0172
# 	🎯 Test Accuracy: 75.57%
